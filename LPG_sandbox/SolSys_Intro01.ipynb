# %% [markdown]
# <img align="left" src = https://dirac.astro.washington.edu/wp-content/uploads/2022/03/DIRAC_logo-purple-text_transparent-bckg_ALPHA-1-1.png
#  width=190 style="padding: 10px">
# <br><b>Introduction to the DP0.3 Moving Object Catalogs</b> <br>
# Contact author: Bob Abel <br>
# Last verified to run: 2023-06-17 <br>
# LSST Science Piplines version: Weekly 2023_21 <br>
# Container size: medium <br>
# Targeted learning level: beginner <br>
# <br>
# <figcaption align = "left"><b>&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;DiRAC Institute</b></figcaption>

# %% [markdown]
# **Description:** DP0.3 moving object catalogs are examined.<br>**Skills:** Discover moving object catalogs and create plots for preliminary analysis. <br>**LSST Data Products:** TAP dp03_catalogs <br>**Credits:** Mario Jurić and literally every single contributing author to the Rubin Stack Club, DP0 Tutorial, and Delegate Contribution <br>&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;Jupyter Notebooks, and Jake Vanderplas.

# %% [markdown]
# ## <span style='color:blue'> Table of Contents </span>
# ### <span style='color:blue'> 1. Import Modules<br>2. Examine Schemas<br>3. MPCORB<br>4. SSObject<br>5. SSSource<br>6. DiaSource</span>

# %% [markdown]
# ### <span style='color:blue'> 1. Import Modules</span>
# #### <span style='color:blue'> Import the data as "ssotap" instead of "tap".</span>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colormaps

from lsst.rsp import get_tap_service, retrieve_query

service = get_tap_service("ssotap")

# %% [markdown]
# ### <span style='color:blue'> 2. What are the Moving Object schemas? </span>

# %%
query = "SELECT * FROM tap_schema.schemas"
results = service.search(query)
print(type(results))
# Out:
# <class 'pyvo.dal.tap.TAPResults'>

# %%
results = service.search(query).to_table().to_pandas()
results
# Out:
#                                          description  schema_index
# 0  Data Preview 0.3 contains the catalog products...             0  \
# 1  A TAP-standard-mandated schema to describe tab...        100000
# 2                                       UWS Metadata        120000
#
#      schema_name utype
# 0  dp03_catalogs
# 1     tap_schema
# 2            uws

# %% [markdown]
# ### <span style='color:blue'> What's in the DP0.3 catalogs? </span>

# %%
schema_names = results['schema_name']
for name in schema_names:
    if name.find('dp03') > -1:
        dp03_schema_name = name
        break
print("DP0.3 schema is " + dp03_schema_name)
# Out:
# DP0.3 schema is dp03_catalogs

# %%
query = "SELECT * FROM tap_schema.tables " \
        "WHERE tap_schema.tables.schema_name = '" \
        + dp03_schema_name + "' order by table_index ASC"
print(query)

results = service.search(query)
results = results.to_table()
results
# Out:
# SELECT * FROM tap_schema.tables WHERE tap_schema.tables.schema_name = 'dp03_catalogs' order by table_index ASC
# <Table length=4>
#                                                                                        description                                                                                        ...
#                                                                                           str512                                                                                          ...
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# The orbit catalog produced by the Minor Planet Center. Ingested daily. O(10M) rows by survey end. The columns are described at https://minorplanetcenter.net//iau/info/MPOrbitFormat.html ...
#                                                                               LSST-computed per-object quantities. 1:1 relationship with MPCORB. Recomputed daily, upon MPCORB ingestion. ...
#                                                                            LSST-computed per-source quantities. 1:1 relationship with DIASource. Recomputed daily, upon MPCORB ingestion. ...
#                                                                                            Table to store 'difference image sources'; - sources detected at SNR >=5 on difference images. ...

# %% [markdown]
# ## <span style='color:blue'> 3. What's in the MPCORB catalog and how big is it?</span>

# %%
results = service.search("SELECT COUNT(*) from dp03_catalogs.MPCORB")
results.to_table().to_pandas()
# Out:
#       COUNT
# 0  14600302

# %%
df = service.search("SELECT TOP 10000 * FROM dp03_catalogs.MPCORB").to_table().to_pandas()
df
# Out:
# WARNING: UnitsWarning: Unit 'days' not supported by the VOUnit standard. Did you mean daS or das? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;days&#x27; not supported by the VOUnit standard. Did you mean daS or das?</pre>
# WARNING: UnitsWarning: Unit 'MJD' not supported by the VOUnit standard. Did you mean MD, MJ, Md, mD, mJ or md? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;MJD&#x27; not supported by the VOUnit standard. Did you mean MD, MJ, Md, mD, mJ or md?</pre>
# WARNING: UnitsWarning: Unit 'degrees' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;degrees&#x27; not supported by the VOUnit standard. </pre>
# WARNING: UnitsWarning: Unit 'day' not supported by the VOUnit standard. Did you mean daJy, daRy or dayr? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;day&#x27; not supported by the VOUnit standard. Did you mean daJy, daRy or dayr?</pre>
#       arc arcEnd arcStart computer        e    epoch  flags fullDesignation
# 0     NaN                           0.56904  54800.0      0   2011 SR000001  \
# 1     NaN                           0.07272  54800.0      0   2011 SR000002
# 2     NaN                           0.25853  54800.0      0   2011 SR000003
# 3     NaN                           0.16372  54800.0      0   2011 SR000004
# 4     NaN                           0.35683  54800.0      0   2011 SR000006
# ...   ...    ...      ...      ...      ...      ...    ...             ...
# 9995  NaN                           0.57394  54800.0      0   2011 SR0004MM
# 9996  NaN                           0.57404  54800.0      0   2011 SR0004MO
# 9997  NaN                           0.62747  54800.0      0   2011 SR0004MQ
# 9998  NaN                           0.38713  54800.0      0   2011 SR0004MR
# 9999  NaN                           0.54538  54800.0      0   2011 SR0004MZ
#
#           incl  lastIncludedObservation  ... nopp       peri  pertsLong
# 0      5.01607                      NaN  ...    0   47.02487             \
# 1     12.20203                      NaN  ...    0  111.14332
# 2     16.23096                      NaN  ...    0   86.93460
# 3     10.94138                      NaN  ...    0  357.05184
# 4     18.91729                      NaN  ...    0  302.03901
# ...        ...                      ...  ...  ...        ...        ...
# 9995  13.11296                      NaN  ...    0  115.22961
# 9996  20.98103                      NaN  ...    0  112.77882
# 9997  13.96506                      NaN  ...    0  281.83500
# 9998   3.00973                      NaN  ...    0  275.32749
# 9999  18.61608                      NaN  ...    0  283.19012
#
#       pertsShort         q  reference  rms           ssObjectId        tperi
# 0                  7.88721             NaN -2658575675934308610  52354.06796  \
# 1                  7.90048             NaN  1638696702905544284  54255.95952
# 2                 18.93842             NaN -6148727610239885338  32718.27775
# 3                  8.90149             NaN  2476339031007217136  49162.23730
# 4                 14.56498             NaN -6439077407999146266 -13278.77515
# ...          ...       ...        ...  ...                  ...          ...
# 9995               9.28789             NaN -8734882002694245648 -16697.67576
# 9996              11.86160             NaN -4671966915883840289  51925.05797
# 9997               6.75318             NaN  5024477766334967041   1766.18754
# 9998               6.28335             NaN  6391222850886637740  31782.45407
# 9999               7.90649             NaN -1098166519394894399   5132.01067
#
#      uncertaintyParameter
# 0
# 1
# 2
# 3
# 4
# ...                   ...
# 9995
# 9996
# 9997
# 9998
# 9999
#
# [10000 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   arc                      0 non-null      float32
#  1   arcEnd                   10000 non-null  object
#  2   arcStart                 10000 non-null  object
#  3   computer                 10000 non-null  object
#  4   e                        10000 non-null  float64
#  5   epoch                    10000 non-null  float64
#  6   flags                    10000 non-null  int32
#  7   fullDesignation          10000 non-null  object
#  8   incl                     10000 non-null  float64
#  9   lastIncludedObservation  0 non-null      float32
#  10  mpcDesignation           10000 non-null  object
#  11  mpcG                     10000 non-null  float32
#  12  mpcH                     10000 non-null  float32
#  13  mpcNumber                10000 non-null  int32
#  14  n                        0 non-null      float64
#  15  nobs                     10000 non-null  int32
#  16  node                     10000 non-null  float64
#  17  nopp                     10000 non-null  int32
#  18  peri                     10000 non-null  float64
#  19  pertsLong                10000 non-null  object
#  20  pertsShort               10000 non-null  object
#  21  q                        10000 non-null  float64
#  22  reference                10000 non-null  object
#  23  rms                      0 non-null      float32
#  24  ssObjectId               10000 non-null  int64
#  25  tperi                    10000 non-null  float64
#  26  uncertaintyParameter     10000 non-null  object
# dtypes: float32(5), float64(8), int32(4), int64(1), object(9)
# memory usage: 1.7+ MB

# %% [markdown]
# ### <span style='color:blue'> Drop the "arc", "lastIncludedObservation:, "n" and "q" columns, since they are all null. </span>

# %%
df = df.drop(columns=['arc', 'lastIncludedObservation', 'n', 'q'])

# %%
df.columns
# Out:
# Index(['arcEnd', 'arcStart', 'computer', 'e', 'epoch', 'flags',
#        'fullDesignation', 'incl', 'mpcDesignation', 'mpcG', 'mpcH',
#        'mpcNumber', 'nobs', 'node', 'nopp', 'peri', 'pertsLong', 'pertsShort',
#        'reference', 'rms', 'ssObjectId', 'tperi', 'uncertaintyParameter'],
#       dtype='object')

# %% [markdown]
# ### <span style='color:blue'> arcStart, arcEnd, computer, mpcG, mpCH pertsLong and pertsShort appear to be all ' ', nobs, nopp appear to all be zero. It looks like rms is all 'nan'. </span>

# %%
# e, epoch, incl, node, peri, rms

fig, ax = plt.subplots(2, 3, figsize=(10, 6))
ax[0,0].hist(df['e'], bins=100)
ax[0,0].set_xlabel('Eccentricity')
ax[0,1].hist(df['node'], bins=100)
ax[0,1].set_xlabel('node')
ax[0,2].hist(df['peri'], bins=100)
ax[0,2].set_xlabel('Periapsis')
ax[1,0].hist(df['epoch'], bins=100)
ax[1,0].set_xlabel('epoch')
ax[1,1].hist(df['incl'], bins=100)
ax[1,1].set_xlabel('Inclination')
ax[1,2].hist(df['mpcH'], bins=100)
ax[1,2].set_xlabel('mpCH')
fig.suptitle('Some MPCORB Histograms')
# Out:
# Text(0.5, 0.98, 'Some MPCORB Histograms')

# %%
plt.figure(figsize=(5,3))
plt.scatter(df['mpcG'], df['mpcH'])
plt.gca().invert_yaxis()
plt.xlabel('mpcG')
plt.ylabel('mpcH')
# Out:
# Text(0, 0.5, 'mpcH')

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4))
ax[0].hist2d(df['node'], df['e'], bins=100, norm='log')
ax[0].set_xlabel('Node (degrees)')
ax[0].set_ylabel('Eccentricity')
ax[1].hist2d(df['node'], df['incl'], bins=100, norm='log')
ax[1].set_xlabel('Node (degrees)')
ax[1].set_ylabel('Inclination (degrees)')
ax[2].hist2d(df['e'], df['incl'], bins=100, norm='log')
ax[2].set_xlabel('Eccentricity')
ax[2].set_ylabel('Inclination (degrees)')
fig.suptitle("Eccentricity, Node and Inclination")
# Out:
# Text(0.5, 0.98, 'Eccentricity, Node and Inclination')

# %% [markdown]
# ## <span style='color:blue'> 4. What's in the SSObject catalog and how big is it?</span>

# %%
results = service.search("SELECT COUNT(*) from dp03_catalogs.SSObject")
results.to_table().to_pandas()
# Out:
#       COUNT
# 0  10222593

# %%
df = service.search("SELECT TOP 10000 * FROM dp03_catalogs.SSObject").to_table().to_pandas()
df
# Out:
# WARNING: UnitsWarning: Unit 'days' not supported by the VOUnit standard. Did you mean daS or das? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;days&#x27; not supported by the VOUnit standard. Did you mean daS or das?</pre>
# WARNING: UnitsWarning: Unit 'date' not supported by the VOUnit standard. Did you mean daT or dabyte? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;date&#x27; not supported by the VOUnit standard. Did you mean daT or dabyte?</pre>
#               arc  discoverySubmissionDate  firstObservationDate  flags
# 0       23.970633             63485.235127          63478.235127      0  \
# 1      592.858276             63130.249928          63123.249928      0
# 2     3578.774902             60231.320624          60224.320624      0
# 3       27.848423             61395.336431          61388.336431      0
# 4        0.000000             61181.280962          61174.280962      0
# ...           ...                      ...                   ...    ...
# 9995  2656.853271             60679.266150          60672.266150      0
# 9996  2280.793701             60443.353240          60436.353240      0
# 9997  3297.790527             60229.288561          60222.288561      0
# 9998  3340.827393             60413.387635          60406.387635      0
# 9999  3313.094482             60324.196054          60317.196054      0
#
#          gChi2      gG12   gG12Err         gH  gH_gG12_Cov     gHErr  ...
# 0          NaN       NaN       NaN        NaN          NaN       NaN  ...  \
# 1          NaN       NaN       NaN        NaN          NaN       NaN  ...
# 2     1.110242  0.180097  0.057263  20.742580     0.002843  0.054457  ...
# 3          NaN       NaN       NaN        NaN          NaN       NaN  ...
# 4          NaN       NaN       NaN        NaN          NaN       NaN  ...
# ...        ...       ...       ...        ...          ...       ...  ...
# 9995  1.638247  0.416311  0.301014  21.954044     0.035673  0.138750  ...
# 9996       NaN       NaN       NaN        NaN          NaN       NaN  ...
# 9997  0.941097  0.116326  0.011919  18.290657     0.000149  0.013157  ...
# 9998  1.294289  1.115785  0.943503  20.897684     0.370902  0.398333  ...
# 9999  0.658280  0.330833  0.083494  20.079460     0.004004  0.052011  ...
#
#       yH_yG12_Cov     yHErr  yNdata     zChi2      zG12   zG12Err         zH
# 0             NaN       NaN       0       NaN       NaN       NaN        NaN  \
# 1             NaN       NaN       0       NaN       NaN       NaN        NaN
# 2             NaN       NaN       0  0.233795  0.210068  0.030876  19.977598
# 3             NaN       NaN       0       NaN       NaN       NaN        NaN
# 4             NaN       NaN       0       NaN       NaN       NaN        NaN
# ...           ...       ...     ...       ...       ...       ...        ...
# 9995          NaN       NaN       0       NaN       NaN       NaN        NaN
# 9996          NaN       NaN       0       NaN       NaN       NaN        NaN
# 9997     0.001369  0.037019      32  1.505396  0.162155  0.032137  17.734968
# 9998          NaN       NaN       0       NaN       NaN       NaN        NaN
# 9999          NaN       NaN       0       NaN       NaN       NaN        NaN
#
#       zH_zG12_Cov     zHErr  zNdata
# 0             NaN       NaN       0
# 1             NaN       NaN       0
# 2        0.000846  0.030486      11
# 3             NaN       NaN       0
# 4             NaN       NaN       0
# ...           ...       ...     ...
# 9995          NaN       NaN       0
# 9996          NaN       NaN       0
# 9997     0.000974  0.031842      55
# 9998          NaN       NaN       0
# 9999          NaN       NaN       0
#
# [10000 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 55 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   arc                      10000 non-null  float32
#  1   discoverySubmissionDate  10000 non-null  float64
#  2   firstObservationDate     10000 non-null  float64
#  3   flags                    10000 non-null  int64
#  4   gChi2                    4685 non-null   float32
#  5   gG12                     4685 non-null   float32
#  6   gG12Err                  4685 non-null   float32
#  7   gH                       4685 non-null   float32
#  8   gH_gG12_Cov              4685 non-null   float32
#  9   gHErr                    4685 non-null   float32
#  10  gNdata                   10000 non-null  int32
#  11  iChi2                    5061 non-null   float32
#  12  iG12                     5061 non-null   float32
#  13  iG12Err                  5061 non-null   float32
#  14  iH                       5061 non-null   float32
#  15  iH_iG12_Cov              5061 non-null   float32
#  16  iHErr                    5061 non-null   float32
#  17  iNdata                   10000 non-null  int32
#  18  maxExtendedness          10000 non-null  float32
#  19  medianExtendedness       10000 non-null  float32
#  20  minExtendedness          10000 non-null  float32
#  21  MOID                     10000 non-null  float32
#  22  MOIDDeltaV               10000 non-null  float32
#  23  MOIDEclipticLongitude    10000 non-null  float32
#  24  MOIDTrueAnomaly          10000 non-null  float32
#  25  numObs                   10000 non-null  int32
#  26  rChi2                    6307 non-null   float32
#  27  rG12                     6307 non-null   float32
#  28  rG12Err                  6307 non-null   float32
#  29  rH                       6307 non-null   float32
#  30  rH_rG12_Cov              6307 non-null   float32
#  31  rHErr                    6307 non-null   float32
#  32  rNdata                   10000 non-null  int32
#  33  ssObjectId               10000 non-null  int64
#  34  uChi2                    962 non-null    float32
#  35  uG12                     962 non-null    float32
#  36  uG12Err                  962 non-null    float32
#  37  uH                       962 non-null    float32
#  38  uH_uG12_Cov              962 non-null    float32
#  39  uHErr                    962 non-null    float32
#  40  uNdata                   10000 non-null  int32
#  41  yChi2                    1929 non-null   float32
#  42  yG12                     1929 non-null   float32
#  43  yG12Err                  1929 non-null   float32
#  44  yH                       1929 non-null   float32
#  45  yH_yG12_Cov              1929 non-null   float32
#  46  yHErr                    1929 non-null   float32
#  47  yNdata                   10000 non-null  int32
#  48  zChi2                    3221 non-null   float32
#  49  zG12                     3221 non-null   float32
#  50  zG12Err                  3221 non-null   float32
#  51  zH                       3221 non-null   float32
#  52  zH_zG12_Cov              3221 non-null   float32
#  53  zHErr                    3221 non-null   float32
#  54  zNdata                   10000 non-null  int32
# dtypes: float32(44), float64(2), int32(7), int64(2)
# memory usage: 2.3 MB

# %%
# Drop nan Columns:

print('Number of rows before dropping all rows with NaNs: %d' %len(df))
df = df.dropna()
print('Number of rows after dropping all rows with NaNs: %d' %len(df))
# Out:
# Number of rows before dropping all rows with NaNs: 10000
# Number of rows after dropping all rows with NaNs: 960

# %%
print(len(df))
df = df.dropna()
print(len(df))
df.reset_index()
# Out:
# 960
# 960
#      index          arc  discoverySubmissionDate  firstObservationDate  flags
# 0       11  3426.781738             60381.347436          60374.347436      0  \
# 1       20  3391.607666             60329.363118          60322.363118      0
# 2       22  3379.635498             60435.427925          60428.427925      0
# 3       25  3302.609863             60417.416868          60410.416868      0
# 4       42  3498.770020             60234.197159          60227.197159      0
# ..     ...          ...                      ...                   ...    ...
# 955   9936  3592.135498             60226.059416          60219.059416      0
# 956   9939  2711.893555             61043.111822          61036.111822      0
# 957   9967  3393.615479             60398.366217          60391.366217      0
# 958   9992  3231.861572             60337.369490          60330.369490      0
# 959   9997  3297.790527             60229.288561          60222.288561      0
#
#         gChi2      gG12   gG12Err         gH  gH_gG12_Cov  ...  yH_yG12_Cov
# 0    0.744022  0.161918  0.014414  18.332722     0.000113  ...     0.001446  \
# 1    1.545100  0.141859  0.021957  17.520332     0.000414  ...     0.005180
# 2    1.659221  0.146537  0.006197  15.691534     0.000024  ...     0.000087
# 3    1.326712  0.131639  0.003136  16.579573     0.000011  ...     0.000013
# 4    1.415306  0.137497  0.014105  17.767820     0.000149  ...     0.000265
# ..        ...       ...       ...        ...          ...  ...          ...
# 955  1.767395  0.162699  0.005560  15.707813     0.000023  ...     0.000096
# 956  1.209709  0.142608  0.004350  15.589643     0.000017  ...     0.000192
# 957  2.724931  0.185672  0.008904  16.741154     0.000042  ...     0.000307
# 958  8.608109  0.141855  0.004271  15.360290     0.000015  ...     0.000005
# 959  0.941097  0.116326  0.011919  18.290657     0.000149  ...     0.001369
#
#         yHErr  yNdata     zChi2      zG12   zG12Err         zH  zH_zG12_Cov
# 0    0.028723      38  1.006063  0.218915  0.028447  17.779135     0.000479  \
# 1    0.061410      20  0.830705  0.187060  0.030160  16.965273     0.000652
# 2    0.008216     103  1.537985  0.151883  0.005703  14.903973     0.000023
# 3    0.003780      44  1.137314  0.128669  0.002602  15.781694     0.000008
# 4    0.015157      78  1.028455  0.120799  0.013204  16.940821     0.000137
# ..        ...     ...       ...       ...       ...        ...          ...
# 955  0.008887      63  1.160422  0.139681  0.006639  14.890952     0.000033
# 956  0.013914      60  1.114973  0.134745  0.008501  14.789541     0.000065
# 957  0.016078      90  0.875689  0.151696  0.010717  16.119276     0.000080
# 958  0.002215      72  1.379135  0.133668  0.001967  14.555643     0.000004
# 959  0.037019      32  1.505396  0.162155  0.032137  17.734968     0.000974
#
#         zHErr  zNdata
# 0    0.018848      87
# 1    0.023244      49
# 2    0.004429      99
# 3    0.003050      55
# 4    0.011136      88
# ..        ...     ...
# 955  0.005322      78
# 956  0.007980      65
# 957  0.008165      91
# 958  0.002085      66
# 959  0.031842      55
#
# [960 rows x 56 columns]

# %%
# Calculate colors

df['ug'] = df['uH'] - df['gH']
df['gr'] = df['gH'] - df['rH']
df['ri'] = df['rH'] - df['iH']
df['iz'] = df['iH'] - df['zH']
df['zy'] = df['zH'] - df['yH']

# %%
colors = ['ug', 'gr', 'ri', 'iz', 'zy']
filters = ['u', 'g', 'r', 'i', 'z', 'i']
fig, ax = plt.subplots(2, 2, figsize=(10,7))
m = 0
ax[0, 0].hist2d(df['ug'], df['gr'], bins=100, norm='log')
ax[0, 0].set_xlabel('u - g')
ax[0, 0].set_ylabel('g - r')
ax[0, 1].hist2d(df['gr'], df['ri'], bins=100, norm='log')
ax[0, 1].set_xlabel('g - r')
ax[0, 1].set_ylabel('r - i')
ax[1, 0].hist2d(df['ri'], df['iz'], bins=100, norm='log')
ax[1, 0].set_xlabel('r - i')
ax[1, 0].set_ylabel('i - z')
ax[1, 1].hist2d(df['iz'], df['zy'], bins=100, norm='log')
ax[1, 1].set_xlabel('i - z')
ax[1, 1].set_ylabel('z - y')
fig.suptitle('Color-Color Plots for SSObject Catalog')
# Out:
# Text(0.5, 0.98, 'Color-Color Plots for SSObject Catalog')

# %%
df.columns
# Out:
# Index(['arc', 'discoverySubmissionDate', 'firstObservationDate', 'flags',
#        'gChi2', 'gG12', 'gG12Err', 'gH', 'gH_gG12_Cov', 'gHErr', 'gNdata',
#        'iChi2', 'iG12', 'iG12Err', 'iH', 'iH_iG12_Cov', 'iHErr', 'iNdata',
#        'maxExtendedness', 'medianExtendedness', 'minExtendedness', 'MOID',
#        'MOIDDeltaV', 'MOIDEclipticLongitude', 'MOIDTrueAnomaly', 'numObs',
#        'rChi2', 'rG12', 'rG12Err', 'rH', 'rH_rG12_Cov', 'rHErr', 'rNdata',
#        'ssObjectId', 'uChi2', 'uG12', 'uG12Err', 'uH', 'uH_uG12_Cov', 'uHErr',
#        'uNdata', 'yChi2', 'yG12', 'yG12Err', 'yH', 'yH_yG12_Cov', 'yHErr',
#        'yNdata', 'zChi2', 'zG12', 'zG12Err', 'zH', 'zH_zG12_Cov', 'zHErr',
#        'zNdata', 'ug', 'gr', 'ri', 'iz', 'zy'],
#       dtype='object')

# %%
plt.figure(figsize=(5,4))
plt.hist2d(df['gHErr'], df['gH'], bins=100, norm='log')
plt.gca().invert_yaxis()
plt.xlabel('H Error')
plt.ylabel('H (mag)')
plt.title('gHErr vs. gH')
# Out:
# Text(0.5, 1.0, 'gHErr vs. gH')

# %% [markdown]
# ## <span style='color:blue'> 5. What's in the SSSource catalog and how big is it?</span>

# %%
results = service.search("SELECT COUNT(*) from dp03_catalogs.SSSource")
results.to_table().to_pandas()
# Out:
#         COUNT
# 0  1031389589

# %%
df = service.search("SELECT TOP 10000 * FROM dp03_catalogs.SSSource").to_table().to_pandas()
df
# Out:
#               diaSourceId  eclipticBeta  eclipticLambda  galacticB
# 0    -6677207320886083738    -14.796937        0.275643 -74.983697  \
# 1     2187377420519878483    -14.798513        0.273838 -74.985298
# 2     7710902302487823515     -8.514664      323.399988 -49.667501
# 3     -271356953288323193      2.993032      223.464466  40.926764
# 4    -8697932825673254210      2.992054      223.471261  40.920805
# ...                   ...           ...             ...        ...
# 9995  2165369312305495559    -17.535232      293.050418 -28.256429
# 9996  3878803426019511060     -7.039276      271.273407  -4.572098
# 9997 -5636504962884249340     -7.036857      271.272760  -4.570348
# 9998  2869090248556322883      0.674868      291.216392 -17.926442
# 9999 -7331735365947724001     -5.504792      314.832351 -41.022568
#
#        galacticL  heliocentricDist  heliocentricVX  heliocentricVY
# 0      97.325984          2.714209        0.001535        0.009362  \
# 1      97.319338          2.714179        0.001534        0.009363
# 2      30.663622          2.838660        0.006527        0.007276
# 3     341.729632          2.788173        0.009592       -0.004019
# 4     341.734121          2.788179        0.009592       -0.004018
# ...          ...               ...             ...             ...
# 9995    1.434944          2.598016        0.009718        0.002557
# 9996    0.882456          2.269883        0.011348        0.004711
# 9997    0.884250          2.269839        0.011348        0.004712
# 9998   17.898947          2.381575        0.008110        0.007178
# 9999   26.989307          2.380291        0.008583        0.006338
#
#       heliocentricVZ  heliocentricX  ...  residualDec  residualRa
# 0           0.004462       2.581631  ...          NaN         NaN  \
# 1           0.004463       2.581669  ...          NaN         NaN
# 2           0.001231       2.282524  ...          NaN         NaN
# 3          -0.003233      -1.211055  ...          NaN         NaN
# 4          -0.003233      -1.210826  ...          NaN         NaN
# ...              ...            ...  ...          ...         ...
# 9995        0.005756       1.461511  ...          NaN         NaN
# 9996        0.003836       0.760745  ...          NaN         NaN
# 9997        0.003837       0.761016  ...          NaN         NaN
# 9998        0.003391       1.368240  ...          NaN         NaN
# 9999        0.001697       1.556388  ...          NaN         NaN
#
#                ssObjectId  topocentricDist  topocentricVX  topocentricVY
# 0     3170741736075811932         1.903268      -0.010019      -0.002330  \
# 1     3170741736075811932         1.903025      -0.009980      -0.002347
# 2    -3138627559327309764         1.833599      -0.003113      -0.005791
# 3      621582377523519051         2.833449       0.000118      -0.017048
# 4      621582377523519051         2.833760       0.000117      -0.017085
# ...                   ...              ...            ...            ...
# 9995  9114396845358474813         1.706799      -0.000227      -0.010260
# 9996   315247795853964551         1.437760      -0.000518      -0.006713
# 9997   315247795853964551         1.437911      -0.000491      -0.006742
# 9998  2382345053514857016         1.475881      -0.001582      -0.005843
# 9999 -6284452005189280891         1.375089      -0.005113      -0.003030
#
#       topocentricVZ  topocentricX  topocentricY  topocentricZ
# 0         -0.000515      1.840129      0.201474     -0.442451
# 1         -0.000516      1.839880      0.201416     -0.442464
# 2         -0.004332      1.455820     -0.883979     -0.679156
# 3         -0.008906     -2.053715     -1.844714     -0.638527
# 4         -0.008907     -2.053713     -1.845121     -0.638740
# ...             ...           ...           ...           ...
# 9995       0.000209      0.637228     -1.169420     -1.067502
# 9996      -0.001055      0.031711     -1.238766     -0.729114
# 9997      -0.001056      0.031699     -1.238926     -0.729139
# 9998      -0.002224      0.534071     -1.269142     -0.531291
# 9999      -0.002262      0.965015     -0.838109     -0.507140
#
# [10000 rows x 29 columns]

# %%
plt.figure(figsize=(5,4))
plt.hist2d(df['heliocentricDist'], df['topocentricDist'], bins=100, norm='log')
plt.xlabel('Heliocentric Distance (AU?)')
plt.ylabel('Topocentric Distance (AU?)')
plt.title('heliocentricDist vs. topocentricDist')
# Out:
# Text(0.5, 1.0, 'heliocentricDist vs. topocentricDist')

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['heliocentricX'], df['heliocentricY'], df['heliocentricZ'], c='blue', marker='.')

ax.set_xlabel('heliocentricX')
ax.set_ylabel('heliocentricY')
ax.set_zlabel('heliocentricZ')
ax.set_xlim(-3, 1)
ax.set_ylim(2, 6)
ax.set_zlim(-4, -1)
ax.set_title("Heliocentric Coordinates")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['topocentricX'], df['topocentricY'], df['topocentricZ'], c='red', marker='.')

ax.set_xlabel('topocentricX')
ax.set_ylabel('topocentricY')
ax.set_zlabel('topocentricZ')
ax.set_xlim(-3, 1)
ax.set_ylim(2, 6)
ax.set_zlim(-4, -1)
ax.set_title("Topocentric Coordinates")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diaSourceId              10000 non-null  int64
#  1   eclipticBeta             10000 non-null  float64
#  2   eclipticLambda           10000 non-null  float64
#  3   galacticB                10000 non-null  float64
#  4   galacticL                10000 non-null  float64
#  5   heliocentricDist         10000 non-null  float32
#  6   heliocentricVX           10000 non-null  float32
#  7   heliocentricVY           10000 non-null  float32
#  8   heliocentricVZ           10000 non-null  float32
#  9   heliocentricX            10000 non-null  float32
#  10  heliocentricY            10000 non-null  float32
#  11  heliocentricZ            10000 non-null  float32
#  12  mpcUniqueId              10000 non-null  int64
#  13  phaseAngle               10000 non-null  float32
#  14  predictedDecSigma        0 non-null      float32
#  15  predictedMagnitude       0 non-null      float32
#  16  predictedMagnitudeSigma  0 non-null      float32
#  17  predictedRaDecCov        0 non-null      float32
#  18  predictedRaSigma         0 non-null      float32
#  19  residualDec              0 non-null      float64
#  20  residualRa               0 non-null      float64
#  21  ssObjectId               10000 non-null  int64
#  22  topocentricDist          10000 non-null  float32
#  23  topocentricVX            10000 non-null  float32
#  24  topocentricVY            10000 non-null  float32
#  25  topocentricVZ            10000 non-null  float32
#  26  topocentricX             10000 non-null  float32
#  27  topocentricY             10000 non-null  float32
#  28  topocentricZ             10000 non-null  float32
# dtypes: float32(20), float64(6), int64(3)
# memory usage: 1.4 MB

# %%
plt.figure(figsize=(5,4))
plt.scatter(df['eclipticLambda'], df['eclipticBeta'])
plt.title('eclipticLambda vs. eclipticBeta')
plt.xlabel('Ecliptic λ (deg)')
plt.ylabel('Ecliptic β (deg)')
# Out:
# Text(0, 0.5, 'Ecliptic β (deg)')

# %%
plt.figure(figsize=(5,4))
plt.hist2d(df['galacticL'], df['galacticB'], bins=100, norm='log')
plt.xlabel('Galactic Longitude (deg)')
plt.ylabel('Galactic Latitude (deg)')
# Out:
# Text(0, 0.5, 'Galactic Latitude (deg)')

# %% [markdown]
# ## <span style='color:blue'> 6. What's in the DiaSource catalog and how big is it?</span>

# %%
results = service.search("SELECT COUNT(*) from dp03_catalogs.DiaSource")
results.to_table().to_pandas()
# Out:
#         COUNT
# 0  1031389589

# %%
df = service.search("SELECT TOP 10000 * FROM dp03_catalogs.DiaSource").to_table().to_pandas()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _decTrue             10000 non-null  float64
#  1   _magTrue             10000 non-null  float32
#  2   _name                10000 non-null  object
#  3   _raTrue              10000 non-null  float64
#  4   _V                   10000 non-null  float32
#  5   ccdVisitId           10000 non-null  int64
#  6   decl                 10000 non-null  float64
#  7   declSigma            10000 non-null  float32
#  8   diaObjectId          10000 non-null  int64
#  9   diaSourceId          10000 non-null  int64
#  10  filter               10000 non-null  object
#  11  mag                  10000 non-null  float32
#  12  magSigma             10000 non-null  float32
#  13  midPointTai          10000 non-null  float64
#  14  ra                   10000 non-null  float64
#  15  ra_decl_Cov          10000 non-null  float32
#  16  raSigma              10000 non-null  float32
#  17  snr                  10000 non-null  float32
#  18  ssObjectId           10000 non-null  int64
#  19  ssObjectReassocTime  10000 non-null  object
# dtypes: float32(8), float64(5), int64(4), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# #### <span style='color:blue'> It seems like the true values of ra and dec nearly agree. Does mag add an error function to _magTrue? </span>

# %%
df = service.search("SELECT TOP 10000 * FROM dp03_catalogs.DiaSource").to_table().to_pandas()
df
# Out:
#        _decTrue   _magTrue      _name     _raTrue         _V  ccdVisitId
# 0    -11.958747  19.210653  S10046kNa  333.201789  19.611652     1818925  \
# 1    -47.011324  19.673462  S10046vOa  278.730464  19.928463     1811801
# 2    -47.010822  19.473591  S10046vOa  278.723088  19.928591     1811851
# 3     -4.297411  22.152649  S10046Aia  260.399321  22.553648     1816580
# 4      1.644436  21.321709  S10046Fma  308.728527  21.576708     1814806
# ...         ...        ...        ...         ...        ...         ...
# 9995   3.364648  20.947269  S1000Lona   11.714316  21.348270     1818988
# 9996   3.365971  20.941927  S1000Lona   11.715320  21.347927     1819038
# 9997 -32.173778  23.106585  S1000Lu2a  307.731572  23.561584     1813802
# 9998 -32.174861  23.306232  S1000Lu2a  307.725975  23.561232     1813852
# 9999 -22.136787  23.111567  S1000LDHa  255.595743  22.716568     1814512
#
#            decl  declSigma          diaObjectId          diaSourceId filter
# 0    -11.958745   0.000002 -7886636262184321216  -567964797446602246      z  \
# 1    -47.011325   0.000002  1846394091472750357  3859970301506732990      r
# 2    -47.010822   0.000002 -7172244639703981623 -4963364694958085932      i
# 3     -4.297309   0.000066  5575889414837799862 -1131385749929805541      z
# 4      1.644442   0.000003  5101524416346643952  4115584071209689695      r
# ...         ...        ...                  ...                  ...    ...
# 9995   3.364658   0.000008  7890523659725505231 -8567907773604489362      z
# 9996   3.365969   0.000022  8668314481026276175  7213791367292140050      y
# 9997 -32.173765   0.000007 -3195026958713165138  3851433467497776778      i
# 9998 -32.174852   0.000006  7200954872485936974 -3777623017326948064      r
# 9999 -22.136801   0.000004   131381066533794906 -6492708869160271975      g
#
#             mag  magSigma   midPointTai          ra  ra_decl_Cov   raSigma
# 0     19.198376  0.011198  63433.327690  333.201787          0.0  0.000002  \
# 1     19.679327  0.005233  63420.247629  278.730466          0.0  0.000002
# 2     19.463570  0.007221  63420.272174  278.723088          0.0  0.000002
# 3     21.658239  0.268755  63431.175078  260.399465          0.0  0.000066
# 4     21.324785  0.023615  63427.315026  308.728541          0.0  0.000003
# ...         ...       ...           ...         ...          ...       ...
# 9995  20.829399  0.055003  63433.356306   11.714322          0.0  0.000008
# 9996  20.994724  0.128106  63433.380597   11.715280          0.0  0.000022
# 9997  23.141687  0.091990  63426.322434  307.731569          0.0  0.000007
# 9998  23.224720  0.079408  63426.347025  307.725982          0.0  0.000006
# 9999  23.082155  0.048945  63427.174965  255.595736          0.0  0.000004
#
#              snr           ssObjectId ssObjectReassocTime
# 0      96.455246 -4602328102287818834   63433.32768968839
# 1     206.982452  -783891166647544042   63420.24762919605
# 2     149.850266  -783891166647544042    63420.2721735044
# 3       3.560484  8505176144455262469   63431.17507785477
# 4      45.479225  7656185246622669168   63427.31502562373
# ...          ...                  ...                 ...
# 9995   19.243654   272192554060328859   63433.35630574205
# 9996    7.985127   272192554060328859   63433.38059727543
# 9997   11.309824  2454292233961579371   63426.32243412704
# 9998   13.179036  2454292233961579371  63426.347025283714
# 9999   21.686745  1173008680286538476   63427.17496505075
#
# [10000 rows x 20 columns]

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4))

ax[0].scatter(df['_raTrue'], df['ra'])
ax[0].set_xlabel('_raTrue')
ax[0].set_ylabel('ra')
ax[0].set_title('_raTrue vs. ra')

ax[1].scatter(df['_decTrue'], df['decl'])
ax[1].set_xlabel('_decTrue')
ax[1].set_ylabel('decl')
ax[1].set_title('_decTrue vs. decl')

ax[2].scatter(df['_magTrue'], df['mag'])
ax[2].set_xlabel('_magTrue')
ax[2].set_ylabel('mag')
ax[2].set_title('_magTrue vs. mag')
ax[2].invert_xaxis()
ax[2].invert_yaxis()

# %%
plt.scatter(df['snr'], (df['mag']))
plt.gca().invert_yaxis()
plt.xlabel('Signal-to-Noise Ratio ("snr")')
plt.ylabel('magnitude ("mag")')
plt.title('Why do lower magnitudes have higher SNR? (All filters here)')
# Out:
# Text(0.5, 1.0, 'Why do lower magnitudes have higher SNR? (All filters here)')

# %% [markdown]
# #### <span style='color:blue'> Try separating the filters into separate tables.

# %%
filter_label = ['u', 'g', 'r', 'i', 'z', 'y']
df_u = df[(df['filter'] == 'u')] 
df_g = df[(df['filter'] == 'g')]
df_r = df[(df['filter'] == 'r')]
df_i = df[(df['filter'] == 'i')]
df_z = df[(df['filter'] == 'z')] 
df_y = df[(df['filter'] == 'y')]

# %%
plot_color = ['violet', 'blue', 'green', 'yellow', 'orange', 'red'] 
fig, ax, = plt.subplots(2, 3, figsize=(10,6))
m = 0
ax[0,0].scatter(df_u['snr'], df_u['mag'], color = plot_color[0], label='u')
ax[0,1].scatter(df_g['snr'], df_g['mag'], color = plot_color[1], label='g')
ax[0,2].scatter(df_r['snr'], df_r['mag'], color = plot_color[2], label='r')
ax[1,0].scatter(df_i['snr'], df_i['mag'], color = plot_color[3], label='i')
ax[1,1].scatter(df_z['snr'], df_z['mag'], color = plot_color[4], label='z')
ax[1,2].scatter(df_y['snr'], df_y['mag'], color = plot_color[5], label='y')
fig.suptitle('SNR vs. apparent magnitude for all filters')
for i in range(2):
    for j in range(3):
        ax[i,j].set_xlabel('SNR')
        ax[i,j].set_ylabel(filter_label[m] + '_mag')
        ax[i,j].invert_yaxis()
        ax[i,j].legend()
        m += 1

# %%
fig, ax, = plt.subplots(2, 3, figsize=(10,6))

ax[0,0].scatter(np.log10(df_u['snr']), df_u['magSigma'], color = plot_color[0], label='u')
ax[0,1].scatter(np.log10(df_g['snr']), df_g['magSigma'], color = plot_color[1], label='g')
ax[0,2].scatter(np.log10(df_r['snr']), df_r['magSigma'], color = plot_color[2], label='r')
ax[1,0].scatter(np.log10(df_i['snr']), df_i['magSigma'], color = plot_color[3], label='i')
ax[1,1].scatter(np.log10(df_z['snr']), df_z['magSigma'], color = plot_color[4], label='z')
ax[1,2].scatter(np.log10(df_y['snr']), df_y['magSigma'], color = plot_color[5], label='y')
fig.suptitle('$Log_{10}$(SNR) vs. ${\sigma}_{m}$ for all filters')
for i in range(2):
    for j in range(3):
        ax[i,j].set_xlabel('log(SNR)')
        ax[i,j].set_ylabel('${\sigma}_{m}$')
        
        ax[i,j].legend()

# %% [markdown]
# #### <span style='color:blue'> The 'magnitude column encompasses all colors (there's a separate 'filter' column) and, as shown below, the number of observations varies for each filter. I think color calculations would focus on ssObjectId. How do we calculate colors for objects? How many observations in how many filters? </span>

# %%
print("There are %d unique ssObjectId's out of %d objects" %(len(np.unique(df['ssObjectId'])), len(df)))
# Out:
# There are 5973 unique ssObjectId's out of 10000 objects

# %%
df = df.sort_values(by=['ssObjectId'])
df = df.reset_index()

# %%
for i in range(37,56):
    print(i, df['ssObjectId'][i], df['mag'][i], df['midPointTai'][i]-60000.)
# Out:
# 37 -9154243313361666897 20.830948 3421.3408879102135
# 38 -9151884868867417891 22.249104 3421.3587742357995
# 39 -9138668375760846028 21.568453 3425.986631790016
# 40 -9135809738265619460 23.423765 3420.201105366614
# 41 -9135809738265619460 23.34846 3420.225799203101
# 42 -9132799761468659034 20.935024 3427.2468230595987
# 43 -9132799761468659034 20.816713 3427.2698756530954
# 44 -9125740991357390963 22.310785 3428.430552412072
# 45 -9125132370845439716 19.998003 3433.258091315234
# 46 -9125132370845439716 20.054844 3433.280849594128
# 47 -9124090096622738890 19.912954 3433.1630348344115
# 48 -9124090096622738890 19.863258 3433.1387093342637
# 49 -9121448729438212674 22.211996 3434.0738594415234
# 50 -9119969746178843911 21.11961 3421.295331308429
# 51 -9119969746178843911 21.028946 3421.3192588789534
# 52 -9114901476807406489 16.019997 3430.98120713151
# 53 -9110734410561767005 21.775269 3430.3057736369665
# 54 -9110734410561767005 21.679579 3430.329555497883
# 55 -9110041204458912482 23.024 3425.9875325080066

# %% [markdown]
# #### <span style='color:blue'> ssObjectId is the moving object identifier, but how should we calculate colors? </span>

# %%
print('# of Entries for each filter:')
print(' u   g   r    i   z   y')
print(len(df_u), len(df_g), len(df_r), len(df_i), len(df_z), len(df_y))
# Out:
# # of Entries for each filter:
#  u   g   r    i   z   y
# 172 499 2605 2899 1900 1925

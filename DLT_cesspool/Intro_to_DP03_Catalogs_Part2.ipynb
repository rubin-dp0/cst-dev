# %% [markdown]
# <img align="left" src = https://project.lsst.org/sites/default/files/Rubin-O-Logo_0.png width=250 style="padding: 10px">
# <br><b>Introduction to the DP0.3 Moving Object Catalogs</b> <br>
# Contact author: Bob Abel and Douglas Tucker<br>
# Last verified to run: 2023-07-09 <br>
# LSST Science Piplines version: Weekly 2023_21 <br>
# Container size: medium <br>
# Targeted learning level: beginner <br>

# %%
# %load_ext pycodestyle_magic
# %flake8_on
import logging
logging.getLogger("flake8").setLevel(logging.FATAL)

# %% [markdown]
# **Description:** DP0.3 moving object catalogs are examined.

# %% [markdown]
# **Skills:** Discover moving object catalogs and create plots for preliminary analysis.

# %% [markdown]
# **LSST Data Products:** TAP dp03_catalogs.

# %% [markdown]
# **Packages:** lsst.rsp.get_tap_service, lsst.rsp.retrieve_query, numpy, matplotlib

# %% [markdown]
# **Credit:**
# Mario Jurić provided essential assistance in the initial stages of creating this notebook.  The notebook authors would also like to acknowledge help from Leanne Guy, Pedro Bernardinelli, Sarah Greenstreet, Megan Schwamb, Brian Rogers, Niall McElroy, and Jake Vanderplass, among others.

# %% [markdown]
# **Get Support:**
# Find DP0.3-related documentation and resources at <a href="https://dp0-3.lsst.io">dp0-3.lsst.io</a>. Questions are welcome as new topics in the <a href="https://community.lsst.org/c/support/dp0">Support - Data Preview 0 Category</a> of the Rubin Community Forum. Rubin staff will respond to all questions posted there.

# %% [markdown]
# ## 1. Introduction
#
# This notebook will teach the user about the basic constituents of the DP0.3 data set.  DP0.3 consists of both real and simulated solar system objects (asteroids, near-earth objects, Trojans, trans-Neptunian objects, and even a simulated spaceship... but no comets, major planets, or the Moon).  It is a hybrid catalog in which objects from the Minor Planet Center have replaced objects with similar properties from the original simulated data set.
#
# Due to time and effort constraints, only catalog data are available.  Also, since the DP0.2 footprint is far from the ecliptic plane, only a very small fraction of DP0.3 would appear within a DP0.2 visit.
#
# For the real objects in the DP0.3, one should consult the `MPCORB` provided instead of querying the actual the Minor Planet Center (see below).
#
# For additional information, please consult
# <a href="https://dp0-3.lsst.io">dp0-3.lsst.io</a>.

# %% [markdown]
# ### 1.1 Package Imports
#
# Import general python packages and the Rubin TAP service utilities.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colormaps
import pandas as pd

from lsst.rsp import get_tap_service, retrieve_query

# %% [markdown]
# ### 1.2 Define Functions and Parameters

# %% [markdown]
# Here, we define a function, `estDistFromHandAlbedo`, which estimates the diameter (in km) of an solar system object based on its solar system absolute magnitude, `H`, and its albedo, `a`.  It assumes a spherical body and is just a rough estimate.  We will use it later.
#
# We obtained this function from https://cneos.jpl.nasa.gov/tools/ast_size_est.html, and we take as a default a *geometric* albedo of `a`=0.15, which is not atypical for, say, an S-class asteroid. The diameter is `estDiam` = $10^{[3.1236 - 0.5log_{10}a - 0.2H]}$.

# %%
def estDiamFromHandAlbedo(H, a=0.15):
    import numpy as np
    estDiam = np.power(10., 3.1236 - 0.5*np.log10(a) - 0.2*H)
    return estDiam

# %% [markdown]
# ## 2. Create the Rubin SSO TAP Service client
#
# Get an instance of the SSO TAP service, and assert that it exists.
#
# _Note that the DP0.3 TAP service for DP0.3 is "ssotap", **not** "tap" (which is used for DP0.2)._

# %%
service = get_tap_service("ssotap")
assert service is not None

# %% [markdown]
# ### 2.1 What are the Moving Object Schemas?
#
# Let's take a look at which schemas are available in DP0.3.

# %%
query = "SELECT * FROM tap_schema.schemas"
results = service.search(query)
print(type(results))
# Out:
# <class 'pyvo.dal.tap.TAPResults'>

# %%
results = service.search(query).to_table().to_pandas()
results
# Out:
#                                          description  schema_index
# 0  Data Preview 0.3 contains the catalog products...             0  \
# 1  A TAP-standard-mandated schema to describe tab...        100000
# 2                                       UWS Metadata        120000
#
#      schema_name utype
# 0  dp03_catalogs
# 1     tap_schema
# 2            uws

# %% [markdown]
# We see that there is a dp03_catalogs schema.  If there were more schemas in the DP0.3 database, we could use the following to find the dp03 schemas specifically:

# %%
schema_names = results['schema_name']
for name in schema_names:
    if name.find('dp03') > -1:
        dp03_schema_name = name
        break
print("DP0.3 schema is " + dp03_schema_name)
# Out:
# DP0.3 schema is dp03_catalogs

# %% [markdown]
# ### 2.2 What are in the DP0.3 catalogs?

# %% [markdown]
# Let's take a quick look at the meta-information for the tables in the `dp03_catalogs` schema.  In the following sections, we will look closer at each of these tables in more detail.

# %%
query = "SELECT * FROM tap_schema.tables " \
        "WHERE tap_schema.tables.schema_name = '" \
        + dp03_schema_name + "' order by table_index ASC"
print(query)

results = service.search(query)
results = results.to_table()
results
# Out:
# SELECT * FROM tap_schema.tables WHERE tap_schema.tables.schema_name = 'dp03_catalogs' order by table_index ASC
# <Table length=4>
#                                                                                        description                                                                                        ...
#                                                                                           str512                                                                                          ...
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# The orbit catalog produced by the Minor Planet Center. Ingested daily. O(10M) rows by survey end. The columns are described at https://minorplanetcenter.net//iau/info/MPOrbitFormat.html ...
#                                                                               LSST-computed per-object quantities. 1:1 relationship with MPCORB. Recomputed daily, upon MPCORB ingestion. ...
#                                                                            LSST-computed per-source quantities. 1:1 relationship with DIASource. Recomputed daily, upon MPCORB ingestion. ...
#                                                                                            Table to store 'difference image sources'; - sources detected at SNR >=5 on difference images. ...

# %% [markdown]
# ## 3. What's in the MPCORB catalog and how big is it?

# %% [markdown]
# Let's first take a look at the `MPCORB` table, which provides an version of the Minor Planet Center orbit catalog relevant for the epochs of the Rubin DP0.3 catalog.

# %%
results = service.search("SELECT COUNT(*) from dp03_catalogs.MPCORB")
results.to_table().to_pandas()
# Out:
#       COUNT
# 0  14600302

# %% [markdown]
# There are 14.6M rows. Let's try to pull out a random 1%, which would be about 146,000 rows.
#
# For the moment, we can try to do this most simply by making use of a temporary trick associated with the current version of the prompt processing data products:  the fact that `ssObjectId` is a randomly assigned 64-bit long unsigned integer.  (Note:  since ADQL interprets a 64-bit long unsigned integer as a 63-bit _signed_ integer, these range from a very large negative integer value to a very large positive integer value.)  To grab a random sample we grab objects over a relatively small range of values of `ssObjectId`.

# %%
results = service.search("""SELECT max(ssObjectId), min(ssObjectId)
                            FROM dp03_catalogs.MPCORB""")

min = int(results[0].get('min'))
max = int(results[0].get('max'))
print('Absolute min, max = ', min, max)
min = int(max - (0.01 * max))
print('1% min, max (from top) = ', min, max)
# Out:
# Absolute min, max =  -9223370383071521539 9223370875126069107
# 1% min, max (from top) =  9131137166374808576 9223370875126069107

# %% [markdown]
# Now, we will grab a random 1% of objects from the `MPCORB` table, making use of the range of `ssObjectId` values we have just found.  (Actually, we will grab a _maximum_ of 1% of objects from the MPCORB table, since the random numbers are not continuous.)
#
# (_Note that you'll have some warnings from this next query that aren't your fault and will be corrected in the future._)

# %%
query = """SELECT *
           FROM dp03_catalogs.MPCORB
           WHERE ssObjectId
           BETWEEN 9131137166374808576 AND 9223370875126069107"""

df = service.search(query).to_table().to_pandas()
df
# Out:
# WARNING: UnitsWarning: Unit 'days' not supported by the VOUnit standard. Did you mean daS or das? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;days&#x27; not supported by the VOUnit standard. Did you mean daS or das?</pre>
# WARNING: UnitsWarning: Unit 'MJD' not supported by the VOUnit standard. Did you mean MD, MJ, Md, mD, mJ or md? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;MJD&#x27; not supported by the VOUnit standard. Did you mean MD, MJ, Md, mD, mJ or md?</pre>
# WARNING: UnitsWarning: Unit 'degrees' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;degrees&#x27; not supported by the VOUnit standard. </pre>
# WARNING: UnitsWarning: Unit 'day' not supported by the VOUnit standard. Did you mean daJy, daRy or dayr? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;day&#x27; not supported by the VOUnit standard. Did you mean daJy, daRy or dayr?</pre>
#        arc arcEnd arcStart computer         e         epoch  flags
# 0      NaN                           0.570970  54800.000000      0  \
# 1      NaN                           0.363600  54800.000000      0
# 2      NaN                           0.422040  54800.000000      0
# 3      NaN                           0.639530  54800.000000      0
# 4      NaN                           0.558600  54800.000000      0
# ...    ...    ...      ...      ...       ...           ...    ...
# 73195  NaN                           0.699330  73349.917495      0
# 73196  NaN                           0.241565  82907.000554      0
# 73197  NaN                           0.563781  61365.350292      0
# 73198  NaN                           0.686982  64269.689620      0
# 73199  NaN                           0.541698  70097.664420      0
#
#       fullDesignation       incl  lastIncludedObservation  ... nopp
# 0       2011 SR00004K  25.939150                      NaN  ...    0  \
# 1       2011 SR0000iQ  16.353220                      NaN  ...    0
# 2       2011 SR0000jR  16.453660                      NaN  ...    0
# 3       2011 SR0000sn  15.263050                      NaN  ...    0
# 4       2011 SR0000O9   2.014410                      NaN  ...    0
# ...               ...        ...                      ...  ...  ...
# 73195   2011 SI00029q   8.924373                      NaN  ...    0
# 73196   2011 SI0002l6   9.715864                      NaN  ...    0
# 73197   2011 SI0002qP   4.110239                      NaN  ...    0
# 73198   2011 SI0002uH   1.053755                      NaN  ...    0
# 73199   2011 SI0002wp  23.764471                      NaN  ...    0
#
#              peri  pertsLong  pertsShort          q  reference  rms
# 0      350.606980                          6.113300             NaN  \
# 1      147.316050                         17.303450             NaN
# 2      274.863090                          6.479600             NaN
# 3      226.268830                          9.611210             NaN
# 4      342.576070                          6.387960             NaN
# ...           ...        ...         ...        ...        ...  ...
# 73195  155.486565                          1.010904             NaN
# 73196   17.733114                          0.974737             NaN
# 73197  152.428342                          0.949081             NaN
# 73198  324.365268                          0.873964             NaN
# 73199   23.457799                          0.323058             NaN
#
#                 ssObjectId         tperi uncertaintyParameter
# 0      9185009465900868832  20859.963850
# 1      9136273658435248197  51070.857800
# 2      9196671585077870249  28521.104640
# 3      9165069355693008015  47926.391840
# 4      9204187278771900476  54049.125620
# ...                    ...           ...                  ...
# 73195  9202444422702896229  72771.929158
# 73196  9177118190137388277  83012.719158
# 73197  9220586587601309840  61834.429501
# 73198  9143316944274961815  65005.664047
# 73199  9137949399332570056  70025.768514
#
# [73200 rows x 27 columns]

# %% [markdown]
# 73200 rows have been returned, but 73200 is not 1% of 14600302.  As noted above, this number is less than 1% of the full number of objects in this table, but it is a large enough number for our current purposes; so let's go with it.
#
# Let's now look at the column information for the data frame we have just created:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73200 entries, 0 to 73199
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   arc                      0 non-null      float32
#  1   arcEnd                   73200 non-null  object
#  2   arcStart                 73200 non-null  object
#  3   computer                 73200 non-null  object
#  4   e                        73200 non-null  float64
#  5   epoch                    73200 non-null  float64
#  6   flags                    73200 non-null  int32
#  7   fullDesignation          73200 non-null  object
#  8   incl                     73200 non-null  float64
#  9   lastIncludedObservation  0 non-null      float32
#  10  mpcDesignation           73200 non-null  object
#  11  mpcG                     73200 non-null  float32
#  12  mpcH                     73200 non-null  float32
#  13  mpcNumber                73200 non-null  int32
#  14  n                        0 non-null      float64
#  15  nobs                     73200 non-null  int32
#  16  node                     73200 non-null  float64
#  17  nopp                     73200 non-null  int32
#  18  peri                     73200 non-null  float64
#  19  pertsLong                73200 non-null  object
#  20  pertsShort               73200 non-null  object
#  21  q                        73200 non-null  float64
#  22  reference                73200 non-null  object
#  23  rms                      0 non-null      float32
#  24  ssObjectId               73200 non-null  int64
#  25  tperi                    73200 non-null  float64
#  26  uncertaintyParameter     73200 non-null  object
# dtypes: float32(5), float64(8), int32(4), int64(1), object(9)
# memory usage: 12.6+ MB

# %% [markdown]
# Here, we will run the pandas `describe` command, which will output some basic population distribution information for the numerical columns in this pandas data frame.

# %%
df.describe()
# Out:
#        arc             e         epoch    flags          incl
# count  0.0  73200.000000  73200.000000  73200.0  73200.000000  \
# mean   NaN      0.172112  54802.108534      0.0     10.972451
# std    NaN      0.107583    604.817406      0.0      7.747464
# min    NaN     -0.002850  54090.500000      0.0      0.000990
# 25%    NaN      0.105540  54800.000000      0.0      5.476818
# 50%    NaN      0.157545  54800.000000      0.0      9.825595
# 75%    NaN      0.211480  54800.000000      0.0     14.184455
# max    NaN      0.999930  90936.183867      0.0    154.846880
#
#        lastIncludedObservation          mpcG          mpcH  mpcNumber    n
# count                      0.0  73200.000000  73200.000000    73200.0  0.0  \
# mean                       NaN      0.150000     20.617786        0.0  NaN
# std                        NaN      0.000048      2.177866        0.0  NaN
# min                        NaN      0.150000      4.760000        0.0  NaN
# 25%                        NaN      0.150000     19.610001        0.0  NaN
# 50%                        NaN      0.150000     20.900000        0.0  NaN
# 75%                        NaN      0.150000     22.040001        0.0  NaN
# max                        NaN      0.150000     26.540001        0.0  NaN
#
#           nobs          node     nopp          peri             q  rms
# count  73200.0  73200.000000  73200.0  73200.000000  73200.000000  0.0  \
# mean       0.0    173.932257      0.0    180.749984      2.440706  NaN
# std        0.0    104.124396      0.0    104.058435      2.278329  NaN
# min        0.0      0.011650      0.0      0.003060      0.011427  NaN
# 25%        0.0     83.460283      0.0     90.570802      1.956770  NaN
# 50%        0.0    167.617815      0.0    181.006430      2.199545  NaN
# 75%        0.0    264.383730      0.0    271.618565      2.574720  NaN
# max        0.0    359.992530      0.0    359.994620     45.345770  NaN
#
#          ssObjectId          tperi
# count  7.320000e+04   73200.000000
# mean   9.177220e+18   52907.162296
# std    2.656485e+16    4542.661808
# min    9.131138e+18  -63479.039930
# 25%    9.154216e+18   52026.268292
# 50%    9.177232e+18   53802.349055
# 75%    9.200119e+18   54421.656843
# max    9.223371e+18  112667.605180

# %% [markdown]
# There are several columns that only contain 'NaN' values.  Let's drop these columns:

# %%
df.dropna(axis=1, how='all', inplace=True)

# %% [markdown]
# Let's also drop any columns that contain only one distinct value (e.g., all columns are ' ' or all columns are 0).  We note that `mpcG` is one of the columns that will be dropped, since it was set to 0.15 for all the rows.

# %%
for col in df.columns:
    if len(df[col].unique()) == 1:
        df.drop(col, inplace=True, axis=1)

# %% [markdown]
# Let's see what columns remain.

# %%
df.columns
# Out:
# Index(['e', 'epoch', 'fullDesignation', 'incl', 'mpcDesignation', 'mpcH',
#        'node', 'peri', 'q', 'ssObjectId', 'tperi'],
#       dtype='object')

# %% [markdown]
# Let's make some histograms for some of the remaining numerical columns.

# %%
fig, ax = plt.subplots(2, 3, figsize=(10, 6))
ax[0, 0].hist(df['e'], bins=100)
ax[0, 0].set_xlabel('Eccentricity')
ax[0, 1].hist(df['node'], bins=100)
ax[0, 1].set_xlabel('node')
ax[0, 2].hist(df['peri'], bins=100)
ax[0, 2].set_xlabel('Periapsis')
ax[1, 0].hist(df['epoch'], bins=100)
ax[1, 0].set_xlabel('epoch')
ax[1, 1].hist(df['incl'], bins=100)
ax[1, 1].set_xlabel('Inclination')
ax[1, 2].hist(df['mpcH'], bins=100)
ax[1, 2].set_xlabel('mpCH')
fig.suptitle('Some MPCORB Histograms')
# Out:
# Text(0.5, 0.98, 'Some MPCORB Histograms')

# %%
df['estDiam'] = estDiamFromHandAlbedo(df['mpcH'])

# %%
df['estDiam'].describe()
# Out:
# count    73200.000000
# mean         0.863328
# std          7.144678
# min          0.016887
# 25%          0.134139
# 50%          0.226754
# 75%          0.410728
# max        383.313629
# Name: estDiam, dtype: float64

# %%
plt.hist(np.log10(df['estDiam']), bins=100)
plt.xlabel('log10(Estimated Diameter [km])')
plt.grid(True)
plt.title('Histogram of Estimated Asteroid Diameters')
# Out:
# Text(0.5, 1.0, 'Histogram of Estimated Asteroid Diameters')

# %% [markdown]
# How do asteroid diameters vary with their orbital argument of perihelion, ω? Not much, judging from the plot below. It looks the most common size is in the 100-300 meter range.

# %%
plt.hist2d(np.log10(df['estDiam']), df['peri'], bins=100, norm='log')
plt.xlabel('Estimated Diameter (km)')
plt.ylabel('Argument of Perihelion, ω (deg)') 
plt.title('Orbital Argument of Perihelion as a function of Asteroid Diameter')
# Out:
# Text(0.5, 1.0, 'Orbital Argument of Perihelion as a function of Asteroid Diameter')
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 3:46: W291 trailing whitespace</pre>

# %% [markdown]
# Look for objects with an argument of perihelion ω < 1.

# %%
mask = df['peri'] < 1.0
plt.hist(np.log10(df['estDiam'][mask]),bins=100)
plt.xlabel('$Log_{10}$(Estimated Diameter)')
plt.title('$Log_{10}$(Estimated Diameter) for Objects with ω < 1')
# Out:
# Text(0.5, 1.0, '$Log_{10}$(Estimated Diameter) for Objects with ω < 1')
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 2:39: E231 missing whitespace after &#x27;,&#x27;</pre>

# %% [markdown]
# Let's also look at some 2D histograms for eccentricity, nodes, and inclination values.

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4))
ax[0].hist2d(df['node'], df['e'], bins=100, norm='log')
ax[0].set_xlabel('Node (degrees)')
ax[0].set_ylabel('Eccentricity')
ax[1].hist2d(df['node'], df['incl'], bins=100, norm='log')
ax[1].set_xlabel('Node (degrees)')
ax[1].set_ylabel('Inclination (degrees)')
ax[2].hist2d(df['e'], df['incl'], bins=100, norm='log')
ax[2].set_xlabel('Eccentricity')
ax[2].set_ylabel('Inclination (degrees)')
fig.suptitle("Eccentricity, Node and Inclination Relative Distributions for DP0.3")
# Out:
# Text(0.5, 0.98, 'Eccentricity, Node and Inclination Relative Distributions for DP0.3')
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:41: E231 missing whitespace after &#x27;,&#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 11:80: E501 line too long (83 &gt; 79 characters)</pre>

# %% [markdown]
# Plot the sine of the inclination (sin(i)) and the eccentricity of the objects as a function of their semi-major axis.  The sin(i) plot compares well with [Figure 5.5 in the LSST Science Book](https://www.lsst.org/sites/default/files/docs/sciencebook/SB_5.pdf).

# %%
df['semi'] = df['q']/(1. - df['e'])
fig, ax = plt.subplots(1, 2, figsize=(10,4))
ax[0].scatter(df['semi'], np.sin(np.pi / 180. * df['incl']), alpha=0.1, s=1)
ax[0].set_xlim(0, 6)
ax[0].set_xlabel('Semi-Major Axis (AU)')
ax[0].set_ylabel('Sin(i)')
ax[0].set_title('Asteroid Semi-Major Axis vs. Inclination') 

ax[1].scatter(df['semi'], df['e'], alpha=0.1, s=1)
ax[1].set_xlim(0, 6)
ax[1].set_xlabel('Semi-Major Axis (AU)')
ax[1].set_ylabel('Eccentricity')
ax[1].set_title('Asteroid Semi-Major Axis vs. Eccentricity')
# Out:
# Text(0.5, 1.0, 'Asteroid Semi-Major Axis vs. Eccentricity')
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 2:41: E231 missing whitespace after &#x27;,&#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 7:60: W291 trailing whitespace</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 13:61: W291 trailing whitespace</pre>

# %% [markdown]
# ## 4. What's in the SSObject catalog and how big is it?
#
# Now let's look at the `SSObject` table.

# %%
results = service.search("SELECT COUNT(*) from dp03_catalogs.SSObject")
results.to_table().to_pandas()
# Out:
#       COUNT
# 0  10222593

# %% [markdown]
# As before, we will consider a random set of objects based on their `ssObjectId` values.

# %%
query = """SELECT *
FROM dp03_catalogs.ssObject
WHERE ssObjectId < 9223370875126069107 AND ssObjectId > 9131137166374808576"""

df = service.search(query).to_table().to_pandas()
df.head()
# Out:
# WARNING: UnitsWarning: Unit 'days' not supported by the VOUnit standard. Did you mean daS or das? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;days&#x27; not supported by the VOUnit standard. Did you mean daS or das?</pre>
# WARNING: UnitsWarning: Unit 'date' not supported by the VOUnit standard. Did you mean daT or dabyte? [astropy.units.format.vounit]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">astropy</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: UnitsWarning: Unit &#x27;date&#x27; not supported by the VOUnit standard. Did you mean daT or dabyte?</pre>
#            arc  discoverySubmissionDate  firstObservationDate  flags
# 0  3089.883301             60599.295358          60592.295358      0  \
# 1    15.927057             61750.270241          61743.270241      0
# 2     2.961222             62806.302010          62799.302010      0
# 3     0.000000             61654.218500          61647.218500      0
# 4  3270.825439             60509.383445          60502.383445      0
#
#       gChi2      gG12   gG12Err         gH  gH_gG12_Cov     gHErr  ...
# 0  1.577042  0.338602  0.202955  21.161713     0.019386  0.106775  ...  \
# 1       NaN       NaN       NaN        NaN          NaN       NaN  ...
# 2       NaN       NaN       NaN        NaN          NaN       NaN  ...
# 3       NaN       NaN       NaN        NaN          NaN       NaN  ...
# 4  1.676326  0.051856  0.138421  18.936575     0.018925  0.141764  ...
#
#    yH_yG12_Cov  yHErr  yNdata     zChi2      zG12   zG12Err         zH
# 0          NaN    NaN       0       NaN       NaN       NaN        NaN  \
# 1          NaN    NaN       0       NaN       NaN       NaN        NaN
# 2          NaN    NaN       0       NaN       NaN       NaN        NaN
# 3          NaN    NaN       0       NaN       NaN       NaN        NaN
# 4          NaN    NaN       0  1.403565  0.171461  0.162144  18.205658
#
#    zH_zG12_Cov     zHErr  zNdata
# 0          NaN       NaN       0
# 1          NaN       NaN       0
# 2          NaN       NaN       0
# 3          NaN       NaN       0
# 4     0.016147  0.108125       9
#
# [5 rows x 55 columns]

# %% [markdown]
# There are 551227 rows.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51227 entries, 0 to 51226
# Data columns (total 55 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   arc                      51227 non-null  float32
#  1   discoverySubmissionDate  51227 non-null  float64
#  2   firstObservationDate     51227 non-null  float64
#  3   flags                    51227 non-null  int64
#  4   gChi2                    23898 non-null  float32
#  5   gG12                     23898 non-null  float32
#  6   gG12Err                  23898 non-null  float32
#  7   gH                       23898 non-null  float32
#  8   gH_gG12_Cov              23898 non-null  float32
#  9   gHErr                    23898 non-null  float32
#  10  gNdata                   51227 non-null  int32
#  11  iChi2                    25998 non-null  float32
#  12  iG12                     25998 non-null  float32
#  13  iG12Err                  25998 non-null  float32
#  14  iH                       25998 non-null  float32
#  15  iH_iG12_Cov              25998 non-null  float32
#  16  iHErr                    25998 non-null  float32
#  17  iNdata                   51227 non-null  int32
#  18  maxExtendedness          51227 non-null  float32
#  19  medianExtendedness       51227 non-null  float32
#  20  minExtendedness          51227 non-null  float32
#  21  MOID                     51227 non-null  float32
#  22  MOIDDeltaV               51227 non-null  float32
#  23  MOIDEclipticLongitude    51227 non-null  float32
#  24  MOIDTrueAnomaly          51227 non-null  float32
#  25  numObs                   51227 non-null  int32
#  26  rChi2                    32579 non-null  float32
#  27  rG12                     32579 non-null  float32
#  28  rG12Err                  32579 non-null  float32
#  29  rH                       32579 non-null  float32
#  30  rH_rG12_Cov              32579 non-null  float32
#  31  rHErr                    32579 non-null  float32
#  32  rNdata                   51227 non-null  int32
#  33  ssObjectId               51227 non-null  int64
#  34  uChi2                    4793 non-null   float32
#  35  uG12                     4793 non-null   float32
#  36  uG12Err                  4793 non-null   float32
#  37  uH                       4793 non-null   float32
#  38  uH_uG12_Cov              4793 non-null   float32
#  39  uHErr                    4793 non-null   float32
#  40  uNdata                   51227 non-null  int32
#  41  yChi2                    9554 non-null   float32
#  42  yG12                     9554 non-null   float32
#  43  yG12Err                  9554 non-null   float32
#  44  yH                       9554 non-null   float32
#  45  yH_yG12_Cov              9554 non-null   float32
#  46  yHErr                    9554 non-null   float32
#  47  yNdata                   51227 non-null  int32
#  48  zChi2                    16529 non-null  float32
#  49  zG12                     16529 non-null  float32
#  50  zG12Err                  16529 non-null  float32
#  51  zH                       16529 non-null  float32
#  52  zH_zG12_Cov              16529 non-null  float32
#  53  zHErr                    16529 non-null  float32
#  54  zNdata                   51227 non-null  int32
# dtypes: float32(44), float64(2), int32(7), int64(2)
# memory usage: 11.5 MB

# %%
df.describe()
# Out:
#                 arc  discoverySubmissionDate  firstObservationDate    flags
# count  51227.000000             51227.000000          51227.000000  51227.0  \
# mean    2237.285645             60877.898365          60870.898365      0.0
# std     1294.815186               811.050318            811.050318      0.0
# min        0.000000             60225.001806          60218.001806      0.0
# 25%     1443.919800             60335.153720          60328.153720      0.0
# 50%     2815.645020             60532.265721          60525.265721      0.0
# 75%     3276.733154             61134.358917          61127.358917      0.0
# max     3595.051025             63819.375091          63812.375091      0.0
#
#               gChi2          gG12       gG12Err            gH   gH_gG12_Cov
# count  23898.000000  23898.000000  23898.000000  23898.000000  2.389800e+04  \
# mean       1.586080      0.207300      0.148309     19.201159  4.723215e-01
# std       19.190218      0.537381      4.926117      1.631289  5.825462e+01
# min        0.008994     -0.363811      0.000689      7.852705  4.783068e-07
# 25%        0.822909      0.132503      0.020725     18.288822  2.988165e-04
# 50%        1.059144      0.161183      0.053647     19.437029  1.963094e-03
# 75%        1.358298      0.214254      0.115312     20.333897  8.869050e-03
# max     2641.300293     65.545464    743.270447     25.592363  8.967290e+03
#
#               gHErr  ...   yH_yG12_Cov        yHErr        yNdata
# count  23898.000000  ...  9.554000e+03  9554.000000  51227.000000  \
# mean       0.067653  ...  7.293496e-01     0.079366      8.030062
# std        0.141413  ...  3.454025e+01     0.216811     23.059311
# min        0.000743  ...  3.732586e-07     0.000598      0.000000
# 25%        0.015811  ...  3.231248e-04     0.017281      0.000000
# 50%        0.039965  ...  2.098327e-03     0.041917      0.000000
# 75%        0.082781  ...  1.058173e-02     0.089246      0.000000
# max       12.064754  ...  3.024482e+03     9.891932    749.000000
#
#               zChi2          zG12       zG12Err            zH   zH_zG12_Cov
# count  16529.000000  16529.000000  16529.000000  16529.000000  1.652900e+04  \
# mean       1.399849      0.242207      0.185852     17.937695  6.459200e-01
# std       21.845818      0.545157      4.346987      1.590755  4.571084e+01
# min        0.010297     -0.370921      0.000860      7.064597  7.848149e-07
# 25%        0.876338      0.138876      0.018814     17.010714  2.625617e-04
# 50%        1.056245      0.166425      0.051439     18.123823  1.899837e-03
# 75%        1.278377      0.237976      0.122705     19.034119  9.744429e-03
# max     2797.307861     41.361580    422.916138     24.245218  4.559956e+03
#
#               zHErr        zNdata
# count  16529.000000  51227.000000
# mean       0.074233     14.292775
# std        0.190788     28.426211
# min        0.000915      0.000000
# 25%        0.015322      0.000000
# 50%        0.039974      0.000000
# 75%        0.086496     15.000000
# max       11.004877    544.000000
#
# [8 rows x 55 columns]

# %% [markdown]
# Let's drop rows that contain any `NaN`'s.

# %%
print('Number of rows before dropping all rows with NaNs: %d' %len(df))
df.dropna(inplace=True)
df.reset_index(inplace=True)
print('Number of rows after dropping all rows with NaNs: %d' %len(df))
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:64: E225 missing whitespace around operator</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 4:63: E225 missing whitespace around operator</pre>
# Number of rows before dropping all rows with NaNs: 51227
# Number of rows after dropping all rows with NaNs: 4774

# %% [markdown]
# Calculate colors - note that these are all absolute ("H") magnitudes.  (For solar system objects, absolute magnitudes are defined to be for an object 1 A.U. from the Sun and 1 A.U. from the observer, and at a phase angle (the angle Sun-object-Earth) of 0 degrees.)

# %%
df['ug'] = df['uH'] - df['gH']
df['gr'] = df['gH'] - df['rH']
df['ri'] = df['rH'] - df['iH']
df['iz'] = df['iH'] - df['zH']
df['zy'] = df['zH'] - df['yH']

# %% [markdown]
# Let's plot some color-color diagrams for these objects.

# %%
colors = ['ug', 'gr', 'ri', 'iz', 'zy']
filters = ['u', 'g', 'r', 'i', 'z', 'i']
fig, ax = plt.subplots(2, 2, figsize=(10,7))
m = 0
ax[0, 0].hist2d(df['ug'], df['gr'], bins=100, norm='log')
ax[0, 0].set_xlabel('u - g')
ax[0, 0].set_ylabel('g - r')
ax[0, 1].hist2d(df['gr'], df['ri'], bins=100, norm='log')
ax[0, 1].set_xlabel('g - r')
ax[0, 1].set_ylabel('r - i')
ax[1, 0].hist2d(df['ri'], df['iz'], bins=100, norm='log')
ax[1, 0].set_xlabel('r - i')
ax[1, 0].set_ylabel('i - z')
ax[1, 1].hist2d(df['iz'], df['zy'], bins=100, norm='log')
ax[1, 1].set_xlabel('i - z')
ax[1, 1].set_ylabel('z - y')
fig.suptitle('Color-Color Plots for SSObject Catalog')
# Out:
# Text(0.5, 0.98, 'Color-Color Plots for SSObject Catalog')
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 3:41: E231 missing whitespace after &#x27;,&#x27;</pre>

# %% [markdown]
# There are only two populations of colors in the simulation; this will obviously change when we look at the real Solar System.

# %% [markdown]
# Now let's look at the estimated statistical error in the g-band absolute magnitude vs. the g-band absolute magnitude.

# %%
plt.figure(figsize=(5,4))
plt.hist2d(df['gHErr'], df['gH'], bins=100, norm='log')
plt.gca().invert_yaxis()
plt.xlabel('H Error')
plt.ylabel('H (mag)')
plt.title('gHErr vs. gH')
# Out:
# Text(0.5, 1.0, 'gHErr vs. gH')
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:22: E231 missing whitespace after &#x27;,&#x27;</pre>

# %% [markdown]
# ## 5. What's in the SSSource catalog and how big is it?
#
# Now let's look at the `SSSource` table.

# %%
results = service.search("SELECT COUNT(*) from dp03_catalogs.SSSource")
results.to_table().to_pandas()
# Out:
#         COUNT
# 0  1031389589

# %% [markdown]
# **_This table contains over a billion sources!_**
#
# As before, we will consider a random set of objects based on their `ssObjectId` values.
# Due to the large size of this table, we'll pull a much smaller data set.

# %%
minSSSource = int(max - (0.001 * max))
minSSSource
# Out:
# 9214147504250943488

# %%
query = """SELECT *
FROM dp03_catalogs.SSSource
WHERE ssObjectId < 9223370875126069107 AND ssObjectId > 9214147504250943488"""

df = service.search(query).to_table().to_pandas()
df.head()
# Out:
#            diaSourceId  eclipticBeta  eclipticLambda  galacticB   galacticL
# 0 -2331882174261098207    -11.977874      214.414018  36.672334  319.926573  \
# 1   867347560563835451    -15.119655      228.103572  25.463550  329.097010
# 2  4057711316122120355    -17.492563      233.362051  20.162046  330.974123
# 3 -4559935229320354350    -17.495300      233.365569  20.157722  330.974360
# 4 -9077906755528548216    -18.699501      234.546349  18.517926  330.821463
#
#    heliocentricDist  heliocentricVX  heliocentricVY  heliocentricVZ
# 0          2.250939        0.002137       -0.010669       -0.005300  \
# 1          2.255840        0.004214       -0.010336       -0.004617
# 2          2.263776        0.005438       -0.009930       -0.004100
# 3          2.263787        0.005439       -0.009930       -0.004099
# 4          2.269094        0.006015       -0.009674       -0.003821
#
#    heliocentricX  ...  residualDec  residualRa           ssObjectId
# 0      -2.165653  ...          NaN         NaN  9214148730396380762  \
# 1      -2.044600  ...          NaN         NaN  9214148730396380762
# 2      -1.928697  ...          NaN         NaN  9214148730396380762
# 3      -1.928556  ...          NaN         NaN  9214148730396380762
# 4      -1.860042  ...          NaN         NaN  9214148730396380762
#
#    topocentricDist  topocentricVX  topocentricVY  topocentricVZ  topocentricX
# 0         2.381151       0.019189      -0.006483      -0.003577     -1.921621  \
# 1         1.948943       0.014820       0.002563       0.000875     -1.256424
# 2         1.688748       0.009464       0.005736       0.002600     -0.961168
# 3         1.688483       0.009424       0.005720       0.002601     -0.960923
# 4         1.573394       0.006459       0.006365       0.003044     -0.864463
#
#    topocentricY  topocentricZ
# 0     -1.011252     -0.977048
# 1     -1.082706     -1.023486
# 2     -0.983861     -0.979817
# 3     -0.983713     -0.979750
# 4     -0.913176     -0.945717
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514641 entries, 0 to 514640
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   diaSourceId              514641 non-null  int64
#  1   eclipticBeta             514641 non-null  float64
#  2   eclipticLambda           514641 non-null  float64
#  3   galacticB                514641 non-null  float64
#  4   galacticL                514641 non-null  float64
#  5   heliocentricDist         514641 non-null  float32
#  6   heliocentricVX           514641 non-null  float32
#  7   heliocentricVY           514641 non-null  float32
#  8   heliocentricVZ           514641 non-null  float32
#  9   heliocentricX            514641 non-null  float32
#  10  heliocentricY            514641 non-null  float32
#  11  heliocentricZ            514641 non-null  float32
#  12  mpcUniqueId              514641 non-null  int64
#  13  phaseAngle               514641 non-null  float32
#  14  predictedDecSigma        0 non-null       float32
#  15  predictedMagnitude       0 non-null       float32
#  16  predictedMagnitudeSigma  0 non-null       float32
#  17  predictedRaDecCov        0 non-null       float32
#  18  predictedRaSigma         0 non-null       float32
#  19  residualDec              0 non-null       float64
#  20  residualRa               0 non-null       float64
#  21  ssObjectId               514641 non-null  int64
#  22  topocentricDist          514641 non-null  float32
#  23  topocentricVX            514641 non-null  float32
#  24  topocentricVY            514641 non-null  float32
#  25  topocentricVZ            514641 non-null  float32
#  26  topocentricX             514641 non-null  float32
#  27  topocentricY             514641 non-null  float32
#  28  topocentricZ             514641 non-null  float32
# dtypes: float32(20), float64(6), int64(3)
# memory usage: 74.6 MB

# %%
df.describe()
# Out:
#         diaSourceId   eclipticBeta  eclipticLambda      galacticB
# count  5.146410e+05  514641.000000   514641.000000  514641.000000  \
# mean  -5.952742e+15      -3.701235      208.294930       3.030559
# std    5.327392e+18      10.615636       95.572246      43.940750
# min   -9.223370e+18     -78.895823        0.000110     -89.355725
# 25%   -4.616143e+18     -10.085485      151.349264     -38.152249
# 50%   -1.154355e+16      -3.226727      212.891568       7.242929
# 75%    4.607900e+18       3.165067      288.083655      43.040545
# max    9.223332e+18      39.092158      359.999502      84.298126
#
#            galacticL  heliocentricDist  heliocentricVX  heliocentricVY
# count  514641.000000     514641.000000   514641.000000   514641.000000  \
# mean      181.262754          3.096603        0.002028       -0.000536
# std       122.584546          3.530645        0.006618        0.007269
# min         0.000281          0.744730       -0.018952       -0.017738
# 25%        46.722281          2.370547       -0.003329       -0.007495
# 50%       205.266317          2.729405        0.002902       -0.001691
# 75%       294.929465          3.054730        0.007876        0.006801
# max       359.999691         61.776371        0.020334        0.020581
#
#        heliocentricVZ  heliocentricX  ...  residualDec  residualRa
# count   514641.000000  514641.000000  ...          0.0         0.0  \
# mean        -0.000260      -0.366229  ...          NaN         NaN
# std          0.003538       3.801769  ...          NaN         NaN
# min         -0.012280     -40.017704  ...          NaN         NaN
# 25%         -0.003271      -2.232736  ...          NaN         NaN
# 50%         -0.000696      -0.587253  ...          NaN         NaN
# 75%          0.002817       1.767071  ...          NaN         NaN
# max          0.014676      41.551609  ...          NaN         NaN
#
#          ssObjectId  topocentricDist  topocentricVX  topocentricVY
# count  5.146410e+05    514641.000000  514641.000000  514641.000000  \
# mean   9.218747e+18         2.318356       0.000286       0.000642
# std    2.631924e+15         3.548721       0.007399       0.006689
# min    9.214149e+18         0.037801      -0.025535      -0.023141
# 25%    9.216452e+18         1.538960      -0.005578      -0.004748
# 50%    9.218757e+18         1.921308      -0.000211       0.001059
# 75%    9.221033e+18         2.309346       0.006214       0.005947
# max    9.223370e+18        62.031693       0.026307       0.024646
#
#        topocentricVZ   topocentricX   topocentricY   topocentricZ
# count  514641.000000  514641.000000  514641.000000  514641.000000
# mean        0.000247      -0.298279      -0.356570      -0.291738
# std         0.003156       3.466460       2.155902       1.003628
# min        -0.014014     -40.558441     -30.408916     -15.749660
# 25%        -0.002017      -1.528473      -1.250798      -0.632720
# 50%         0.000380      -0.337200      -0.468871      -0.247681
# 75%         0.002517       1.092320       0.611109       0.084729
# max         0.015050      42.272457      53.308113      24.618116
#
# [8 rows x 29 columns]

# %% [markdown]
# Plot the difference between asteroid heliocentric distance and topocentric distance as a function of heliocentric distance. It produces a not-unexpected difference range from about -.7 to 1.0 AU. Note also the heliocentric distribution of asteroids between inner/main belt asteroids and the Kuiper belt.

# %%
plt.figure(figsize=(5,4))
plt.hist2d(df['heliocentricDist'], (df['heliocentricDist'] - df['topocentricDist']), bins=100, norm='log')
plt.xlabel('Heliocentric Distance (AU)')
plt.ylabel('Heliocentric - Topocentric Distance (AU)')
plt.title('heliocentricDist vs. the difference between heliocentricDist and topocentricDist')
# Out:
# Text(0.5, 1.0, 'heliocentricDist vs. the difference between heliocentricDist and topocentricDist')
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:22: E231 missing whitespace after &#x27;,&#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 2:80: E501 line too long (106 &gt; 79 characters)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 5:80: E501 line too long (93 &gt; 79 characters)</pre>

# %% [markdown]
# 3-D plots of heliocentric and tropocentric distance show both the inner/main belt and the Kuiper belt  asteroids. At this scale, the inner/main belt populations look like a ball with the sun at its center.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig, ax = plt.subplots(1, 2, subplot_kw={'projection': '3d'}, figsize=(10,4))

ax[0].scatter(df['heliocentricX'], df['heliocentricY'], df['heliocentricZ'], c='blue', marker='.')
ax[0].set_xlabel('heliocentricX')
ax[0].set_ylabel('heliocentricY')
ax[0].set_zlabel('heliocentricZ')
ax[0].set_title("Asteroid Heliocentric Coordinates")

ax[1].scatter(df['topocentricX'], df['topocentricY'], df['topocentricZ'], c='red', marker='.')
ax[1].set_xlabel('topocentricX')
ax[1].set_ylabel('topocentricY')
ax[1].set_zlabel('topocentricZ')
ax[1].set_title("Asteroid Topocentric Coordinates")
plt.show()
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 3:74: E231 missing whitespace after &#x27;,&#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 5:80: E501 line too long (98 &gt; 79 characters)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 11:80: E501 line too long (94 &gt; 79 characters)</pre>

# %% [markdown]
# Check out the asteroid distribution in ecliptic and galactic coordinates. Note the two unusually dense yellow dots in each plot.

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,4))
ax[0].hist2d(df['eclipticLambda'], df['eclipticBeta'], bins=100, norm='log')
ax[0].set_title('eclipticLambda vs. eclipticBeta')
ax[0].set_xlabel('Ecliptic λ (deg)')
ax[0].set_ylabel('Ecliptic β (deg)')

ax[1].hist2d(df['galacticL'], df['galacticB'], bins=100, norm='log')
ax[1].set_title('Galactic Latitude vs. Longitude')
ax[1].set_xlabel('Galactic Longitude (deg)')
ax[1].set_ylabel('Galactic Latitude (deg)')
# Out:
# Text(0, 0.5, 'Galactic Latitude (deg)')
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:41: E231 missing whitespace after &#x27;,&#x27;</pre>

# %% [markdown]
# Now try looking at just one object. Plot its orbit in the XY plane.

# %%
myquery = "SELECT heliocentricX, heliocentricY, topocentricX, topocentricY, ssObjectId" + \
        " FROM dp03_catalogs.SSSource" + \
        " WHERE (ssObjectId =6793512588511170680)"
results = service.search(myquery)
print(type(results))
results = service.search(myquery).to_table().to_pandas()
results
# Out:
# <class 'pyvo.dal.tap.TAPResults'>
#      heliocentricX  heliocentricY  topocentricX  topocentricY
# 0        -1.120697      -1.627495     -0.506155     -2.333641  \
# 1        -1.120668      -1.627519     -0.506084     -2.333634
# 2        -1.082890      -1.657938     -0.414987     -2.322733
# 3        -1.082860      -1.657961     -0.414918     -2.322722
# 4        -1.082831      -1.657984     -0.414848     -2.322711
# ..             ...            ...           ...           ...
# 482      -0.196160       1.952139      0.624825      1.448362
# 483      -1.003959       1.610761     -0.195555      2.160848
# 484      -1.003991       1.610739     -0.195618      2.160866
# 485      -1.004024       1.610717     -0.195680      2.160884
# 486      -1.004056       1.610695     -0.195743      2.160902
#
#               ssObjectId
# 0    6793512588511170680
# 1    6793512588511170680
# 2    6793512588511170680
# 3    6793512588511170680
# 4    6793512588511170680
# ..                   ...
# 482  6793512588511170680
# 483  6793512588511170680
# 484  6793512588511170680
# 485  6793512588511170680
# 486  6793512588511170680
#
# [487 rows x 5 columns]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:80: E501 line too long (91 &gt; 79 characters)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 2:9: E126 continuation line over-indented for hanging indent</pre>

# %%
plt.scatter(results['heliocentricX'], results['heliocentricY'])
plt.grid(True)
plt.xlabel('heliocentric X (AU)')
plt.xlabel('heliocentric Y (AU)')
plt.title('Heliocentric XY path of Object 6793512588511170680')
# Out:
# Text(0.5, 1.0, 'Heliocentric XY path of Object 6793512588511170680')

# %% [markdown]
# ## 6. What's in the DiaSource catalog and how big is it?

# %%
results = service.search("SELECT COUNT(*) from dp03_catalogs.DiaSource")
results.to_table().to_pandas()
# Out:
#         COUNT
# 0  1031389589

# %% [markdown]
# Same situation as SSSource - over a billion objects, so use the same limits as for SSSource.

# %%
query = """SELECT *
FROM dp03_catalogs.DiaSource
WHERE ssObjectId < 9223370875126069107 AND ssObjectId > 9214147504250943488"""

df = service.search(query).to_table().to_pandas()
df
# Out:
#          _decTrue   _magTrue      _name     _raTrue         _V  ccdVisitId
# 0      -24.225311  23.053452  S100sanTa  207.755563  23.308453      674480  \
# 1      -31.678294  23.319633  S100sanTa  220.752671  22.924633      698833
# 2      -35.464861  22.956850  S100sanTa  225.668462  22.561850      715404
# 3      -35.468458  22.306400  S100sanTa  225.671436  22.561399      715454
# 4      -36.946448  21.941467  S100sanTa  226.569719  22.347467      724652
# ...           ...        ...        ...         ...        ...         ...
# 514636 -11.521770  23.644299  S100CSIVa  156.034758  23.942299     1531358
# 514637 -11.707979  24.278765  S100CSIVa  156.347487  23.976765     1530016
# 514638 -11.705734  23.804325  S100CSIVa  156.343467  23.976326     1530066
# 514639  -7.827610  23.973383  S100CSIVa  151.462689  23.671383     1547267
# 514640  -7.449178  23.388176  S100CSIVa  151.102152  23.679176     1548713
#
#              decl  declSigma          diaObjectId          diaSourceId filter
# 0      -24.225271   0.000012 -9194409445772103316 -2331882174261098207      r  \
# 1      -31.678287   0.000004 -6256623948270999662   867347560563835451      g
# 2      -35.464856   0.000004  7731624285748347487  4057711316122120355      g
# 3      -35.468452   0.000004 -2233634430585881080 -4559935229320354350      r
# 4      -36.946441   0.000015 -2049956630163863401 -9077906755528548216      y
# ...           ...        ...                  ...                  ...    ...
# 514636 -11.521731   0.000025 -6931758784898056707 -4630183780981088497      z
# 514637 -11.707973   0.000008 -9108440783752730744  1295083018380555837      g
# 514638 -11.705738   0.000007  4251106071732855350 -7552594750373973562      r
# 514639  -7.827609   0.000015  5639297750535917446 -1597337412419539310      g
# 514640  -7.449200   0.000013  4867431111032961980  3120879741781371708      i
#
#               mag  magSigma   midPointTai          ra  ra_decl_Cov   raSigma
# 0       23.011091  0.105311  61410.336766  207.755559          0.0  0.000012  \
# 1       23.202835  0.051420  61448.322456  220.752679          0.0  0.000004
# 2       22.909597  0.043292  61472.302620  225.668472          0.0  0.000004
# 3       22.361153  0.036251  61472.328547  225.671433          0.0  0.000004
# 4       21.535053  0.155601  61484.286459  226.569734          0.0  0.000015
# ...           ...       ...           ...         ...          ...       ...
# 514636  23.021788  0.296010  62901.247000  156.034691          0.0  0.000025
# 514637  24.082386  0.109329  62899.314036  156.347486          0.0  0.000008
# 514638  23.672674  0.101137  62899.338382  156.343450          0.0  0.000007
# 514639  24.035624  0.134470  62925.243480  151.462688          0.0  0.000015
# 514640  23.324091  0.153133  62927.142207  151.102143          0.0  0.000013
#
#               snr           ssObjectId ssObjectReassocTime
# 0        9.817913  9214148730396380762   61410.33676566108
# 1       20.618900  9214148730396380762   61448.32245558813
# 2       24.582699  9214148730396380762   61472.30261962077
# 3       29.453165  9214148730396380762   61472.32854716052
# 4        6.489630  9214148730396380762  61484.286458514434
# ...           ...                  ...                 ...
# 514636   3.190601  9223370323280082057   62901.24699957877
# 514637   9.439310  9223370323280082057  62899.314036020696
# 514638  10.243048  9223370323280082057  62899.338382013324
# 514639   7.584518  9223370323280082057   62925.24348016973
# 514640   6.601885  9223370323280082057  62927.142207248005
#
# [514641 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514641 entries, 0 to 514640
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   _decTrue             514641 non-null  float64
#  1   _magTrue             514641 non-null  float32
#  2   _name                514641 non-null  object
#  3   _raTrue              514641 non-null  float64
#  4   _V                   514641 non-null  float32
#  5   ccdVisitId           514641 non-null  int64
#  6   decl                 514641 non-null  float64
#  7   declSigma            514641 non-null  float32
#  8   diaObjectId          514641 non-null  int64
#  9   diaSourceId          514641 non-null  int64
#  10  filter               514641 non-null  object
#  11  mag                  514641 non-null  float32
#  12  magSigma             514641 non-null  float32
#  13  midPointTai          514641 non-null  float64
#  14  ra                   514641 non-null  float64
#  15  ra_decl_Cov          514641 non-null  float32
#  16  raSigma              514641 non-null  float32
#  17  snr                  514641 non-null  float32
#  18  ssObjectId           514641 non-null  int64
#  19  ssObjectReassocTime  514641 non-null  object
# dtypes: float32(8), float64(5), int64(4), object(3)
# memory usage: 62.8+ MB

# %%
df.describe()
# Out:
#             _decTrue       _magTrue        _raTrue             _V
# count  514641.000000  514641.000000  514641.000000  514641.000000  \
# mean       -8.362169      22.087826     205.736037      22.282621
# std        15.778328       1.483079      96.947064       1.453877
# min       -75.258849       9.429569       0.000227       9.878193
# 25%       -19.521405      21.286501     149.795347      21.507509
# 50%        -7.969179      22.307749     208.204672      22.519751
# 75%         2.567815      23.157883     287.379848      23.347818
# max        36.040356      25.989101     359.999735      25.724369
#
#          ccdVisitId           decl      declSigma   diaObjectId   diaSourceId
# count  5.146410e+05  514641.000000  514641.000000  5.146410e+05  5.146410e+05  \
# mean   1.032639e+06      -8.362169       0.000010  5.315810e+15 -5.952742e+15
# std    6.023394e+05      15.778328       0.000008  5.324708e+18  5.327392e+18
# min    0.000000e+00     -75.258830       0.000002 -9.223371e+18 -9.223370e+18
# 25%    5.158390e+05     -19.521413       0.000004 -4.614683e+18 -4.616143e+18
# 50%    1.021873e+06      -7.969175       0.000008  1.316806e+16 -1.154355e+16
# 75%    1.574762e+06       2.567839       0.000014  4.615774e+18  4.607900e+18
# max    2.049987e+06      36.040345       0.000192  9.223338e+18  9.223332e+18
#
#                  mag       magSigma    midPointTai             ra
# count  514641.000000  514641.000000  514641.000000  514641.000000  \
# mean       22.055645       0.089892   62025.941355     205.736037
# std         1.455650       0.065307    1062.856572      96.947064
# min         9.429520       0.000040   60218.001806       0.000219
# 25%        21.279406       0.035079   61120.114188     149.795367
# 50%        22.284914       0.079807   61977.016925     208.204670
# 75%        23.115667       0.134276   62971.267210     287.379828
# max        25.234167       0.440071   63813.106689     359.999729
#
#        ra_decl_Cov        raSigma            snr    ssObjectId
# count     514641.0  514641.000000  514641.000000  5.146410e+05
# mean           0.0       0.000010      44.150177  9.218747e+18
# std            0.0       0.000008     335.272217  2.631924e+15
# min            0.0       0.000002       2.000869  9.214149e+18
# 25%            0.0       0.000004       7.596182  9.216452e+18
# 50%            0.0       0.000008      13.110664  9.218757e+18
# 75%            0.0       0.000014      30.453926  9.221033e+18
# max            0.0       0.000192   27247.751953  9.223370e+18

# %% [markdown]
# It seems like the true values of ra, dec and mag nearly agree with the regular values, but the regular values have some regular (Gaussian?) error distribution added.

# %%
fig, ax = plt.subplots(1, 3, figsize=(14,4))

#ax[0].scatter(df['_raTrue'], df['ra'])
ax[0].hist(3600.*(df['ra']-df['_raTrue']), bins=100)
ax[0].set_xlabel('ra - _raTrue [arcsec]')
ax[0].set_ylabel('Number')
ax[0].grid(True)
#ax[0].set_title('_raTrue vs. ra')

#ax[1].scatter(df['_decTrue'], df['decl']
ax[1].hist(3600.*(df['decl']-df['_decTrue']), bins=100)
ax[1].set_xlabel('dec- _ decTrue [arcsec]')
ax[1].set_ylabel('Number')
ax[1].grid(True)
#ax[1].set_title('_decTrue vs. decl')

#ax[2].scatter(df['_magTrue'], df['mag'])
ax[2].hist(df['mag']-df['_magTrue'], bins=100)
ax[2].set_xlabel('mag - _magTrue [mag]')
ax[2].set_ylabel('Number')
ax[2].grid(True)
#ax[2].set_title('mag- _magTrue vs. mag')
#ax[2].invert_xaxis()
#ax[2].invert_yaxis()
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:41: E231 missing whitespace after &#x27;,&#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 3:1: E265 block comment should start with &#x27;# &#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 8:1: E265 block comment should start with &#x27;# &#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 10:1: E265 block comment should start with &#x27;# &#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 15:1: E265 block comment should start with &#x27;# &#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 17:1: E265 block comment should start with &#x27;# &#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 22:1: E265 block comment should start with &#x27;# &#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 23:1: E265 block comment should start with &#x27;# &#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 24:1: E265 block comment should start with &#x27;# &#x27;</pre>

# %%
fig, ax = plt.subplots(1, 3, figsize=(20,6))

ax[0].hist2d(df['_raTrue'], 3600.*(df['ra'] - df['_raTrue']), bins=100, norm='log')
ax[0].set_xlabel('_raTrue')
ax[0].set_ylabel('ra - ra_True [arcsec]')
ax[0].set_title('_raTrue vs. ra')
ax[0].grid(True)

ax[1].hist2d(df['_decTrue'], 3600.*(df['decl'] - df['_decTrue']), bins=100, norm='log')
ax[1].set_xlabel('_decTrue')
ax[1].set_ylabel('decl - _decTrue [arcsec]')
ax[1].set_title('_decTrue vs. decl - _decTrue')
ax[1].grid(True)

ax[2].hist2d(df['_magTrue'], df['mag'] - df['_magTrue'], bins=100, norm='log')
ax[2].set_xlabel('_magTrue')
ax[2].set_ylabel('mag - _magTrue')
ax[2].set_title('_magTrue vs. mag - _magTrue')
ax[2].invert_xaxis()
ax[2].invert_yaxis()
ax[2].grid(True)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:41: E231 missing whitespace after &#x27;,&#x27;</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 3:80: E501 line too long (83 &gt; 79 characters)</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 9:80: E501 line too long (87 &gt; 79 characters)</pre>

# %% [markdown]
# The asteroid distribution as a function of ra and dec is shown below.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist2d(df['ra'], df['decl'], bins=100, norm='log')
plt.xlabel('ra (deg)')
plt.ylabel('declination (deg)')
plt.title('ra vs. dec')
# Out:
# Text(0.5, 1.0, 'ra vs. dec')

# %% [markdown]
# The signal-to-noise ratio increases at lower magnitudes, as it should.

# %%
plt.hist2d(df['mag'], df['snr'], bins=100, norm='log')
plt.gca().invert_xaxis()
plt.xlabel('magnitude ("mag")')
plt.ylabel('Signal-to-Noise Ratio ("snr")')
plt.title('Lower magnitudes have higher SNR')
plt.grid(True)

# %% [markdown]
# Try separating the filters into separate tables.

# %%
filter_label = ['u', 'g', 'r', 'i', 'z', 'y']
df_u = df[(df['filter'] == 'u')] 
df_g = df[(df['filter'] == 'g')]
df_r = df[(df['filter'] == 'r')]
df_i = df[(df['filter'] == 'i')]
df_z = df[(df['filter'] == 'z')] 
df_y = df[(df['filter'] == 'y')]
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 2:33: W291 trailing whitespace</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 6:33: W291 trailing whitespace</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 7:33: W291 trailing whitespace</pre>

# %% [markdown]
# The `magnitude` column encompasses all colors (there's a separate `filter` column) and, as shown below, the number of observations varies for each filter. </span>

# %%
print("There are %d unique ssObjectId's out of %d objects" %(len(np.unique(df['ssObjectId'])), len(df)))
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:61: E225 missing whitespace around operator</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 1:80: E501 line too long (104 &gt; 79 characters)</pre>
# There are 5112 unique ssObjectId's out of 514641 objects

# %%
print('# of Entries for each filter:')
print(' u   g   r    i   z   y')
print(len(df_u), len(df_g), len(df_r), len(df_i), len(df_z), len(df_y))
# Out:
# # of Entries for each filter:
#  u   g   r    i   z   y
# 8360 66771 179173 142721 75912 41704

# %% [markdown]
# Get DiaSource data for the same object studied in the SSSource section.

# %%
myquery = "SELECT decl, mag, midPointTai, ra, ssObjectId" + \
        " FROM dp03_catalogs.DiaSource" + \
        " WHERE (ssObjectId =6793512588511170680)"
df = service.search(myquery).to_table().to_pandas()
df
# Out:
#           decl        mag   midPointTai          ra           ssObjectId
# 0   -21.632050  21.141586  60338.376183  257.762368  6793512588511170680
# 1   -21.632130  20.978247  60338.379279  257.764027  6793512588511170680
# 2   -21.685700  21.180084  60342.378116  259.870221  6793512588511170680
# 3   -21.685735  21.183739  60342.381213  259.871830  6793512588511170680
# 4   -21.685776  21.172150  60342.384312  259.873435  6793512588511170680
# ..         ...        ...           ...         ...                  ...
# 482  16.850791  20.200594  63643.073741   66.664573  6793512588511170680
# 483  19.616284  20.659369  63713.965215   95.171149  6793512588511170680
# 484  19.616278  20.765162  63713.968310   95.172755  6793512588511170680
# 485  19.616254  20.703131  63713.971404   95.174330  6793512588511170680
# 486  19.616224  20.764133  63713.974497   95.175948  6793512588511170680
#
# [487 rows x 5 columns]
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 2:9: E126 continuation line over-indented for hanging indent</pre>

# %% [markdown]
# Plot the obect's ra, dec history, colored by each observation's midpoint TAI value (in days).

# %%
# These color-color plots markers are colored by TAI.

cmap = colormaps['gist_ncar']
fig, ax = plt.subplots(1, 1, figsize=(12,3))
im = ax.scatter(df['ra'], df['decl'], c=df['midPointTai'], cmap=cmap)
ax.set_xlabel('ra (deg)')
ax.set_ylabel('decl (deg)')

fig.suptitle('RA and Dec, Colored by TAI')

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax, label='midPoint Tai')

ax.grid(True)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">pycodestyle</span> <span style="color: var(--jp-info-color0)">INFO</span>: 4:41: E231 missing whitespace after &#x27;,&#x27;</pre>

# %% [markdown]
# The Modified Julian Date (MJD, in days) for this object is plotted vs. absolute magnitude. It appears to have a ~500 day periodicity, plus longer periods probably related to the fact that the the asteroid and our telescope are in different orbits.

# %%
plt.scatter(df['midPointTai'], df['mag'])
plt.gca().invert_yaxis()
plt.xlabel('Modified Julian Date (days)')
plt.ylabel('Magnitude')
plt.title('MJD vs. Magnitude')
plt.grid(True)
